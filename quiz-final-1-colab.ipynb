# %% [markdown]
# ### Data
# Downloaded from: https://www.kaggle.com/divyansh22/flight-delay-prediction
#
# ### Question 1.
# Among all pairs of ORIGIN and DEST, with which
# 1. arrival is delayed (i.e., ARR_DEL15 == 1) at least once in both 2019 and 2020,
# 2. the delayed flight arrives before noon (i.e., ARR_TIME < 1200) in 2019 and after noon (i.e., ARR_TIME >= 1200) in 2020,
#
# how many uique pairs of ORIGIN and DEST that such delays have occurred do we have?
#
# ### 문제 1.
# 2019년과 2020년 데이터의 ORIGIN과 DEST간 비행 기록 중에서,
# 1. 2019년과 2020년 모두 비행기 연착이 발생한 적이 있고
# 2. 또 그 연착된 비행기가 2019년엔 정오 이전에 도착하고 2020년엔 정오 이후에 도착한,
#
# 연착 기록을 찾아 그러한 연착이 일어난 ORIGIN과 DEST 구간의 가지수를 계산하시오.

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 34 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 39.9 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845513 sha256=4fca28a37dba6ebaa02d17931a6863647439d93123e9f00a19c3a7b0835087b9
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

spark = SparkSession.builder.appName('my app').master('local').getOrCreate()
sc = spark.sparkContext

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# (1) 아래 셀에 Jan_2019_ontime.csv 파일을 읽어 data2019 라는 이름의 dataframe을 생성하시오. 같은 식으로 Jan_2020_ontime.csv 파일을 읽어 data2020 라는 이름의 dataframe을 생성하시오. (10점)

# %%
# schema = StructType([
#     StructField('OP_UNIQUE_CARRIER', StringType(), True),
#     StructField('ORIGIN', StringType(), True),
#     StructField('DEST', StringType(), True),
#     StructField('DEP_DEL15', FloatType(), True),
#     StructField('DEP_TIME', FloatType(), True),
# ])

data2019 = spark.read.format("csv").option("sep", ",").option('header', True).load("./January Flight Delay/Jan_2019_ontime.csv")
data2020 = spark.read.format("csv").option("sep", ",").option('header', True).load("./January Flight Delay/Jan_2020_ontime.csv")

# %% [markdown]
# (2) 아래 셀에 data2019 에 결측값이 있는지 확인하는 코드를 작성하시오 (즉, 결측값의 개수를 출력하시오). 같은 식으로 아래 셀에 data2020 에 결측값이 있는지 확인하는 코드를 작성하시오 (10점)

# %%
data2019.select([count(when(isnull(c), c)).alias(c) for c in data2019.columns]).show()
# Out:
# 22/11/10 07:47:54 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST, DEP_TIME, DEP_DEL15, DEP_TIME_BLK, ARR_TIME, ARR_DEL15, CANCELLED, DIVERTED, DISTANCE,
#  Schema: DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST, DEP_TIME, DEP_DEL15, DEP_TIME_BLK, ARR_TIME, ARR_DEL15, CANCELLED, DIVERTED, DISTANCE, _c21
# Expected: _c21 but found:
# CSV file: file:///home/enter1994/notebook/Spark/January%20Flight%20Delay/Jan_2019_ontime.csv
# [Stage 23:>                                                         (0 + 1) / 1]
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+
# |DAY_OF_MONTH|DAY_OF_WEEK|OP_UNIQUE_CARRIER|OP_CARRIER_AIRLINE_ID|OP_CARRIER|TAIL_NUM|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN_AIRPORT_SEQ_ID|ORIGIN|DEST_AIRPORT_ID|DEST_AIRPORT_SEQ_ID|DEST|DEP_TIME|DEP_DEL15|DEP_TIME_BLK|ARR_TIME|ARR_DEL15|CANCELLED|DIVERTED|DISTANCE|  _c21|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+
# |           0|          0|                0|                    0|         0|    2543|                0|                0|                    0|     0|              0|                  0|   0|   16352|    16355|           0|   17061|    18022|        0|       0|       0|583985|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+

# %%
data2020.select([count(when(isnull(c), c)).alias(c) for c in data2020.columns]).show()
# Out:
# 22/11/10 07:47:56 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST, DEP_TIME, DEP_DEL15, DEP_TIME_BLK, ARR_TIME, ARR_DEL15, CANCELLED, DIVERTED, DISTANCE,
#  Schema: DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST, DEP_TIME, DEP_DEL15, DEP_TIME_BLK, ARR_TIME, ARR_DEL15, CANCELLED, DIVERTED, DISTANCE, _c21
# Expected: _c21 but found:
# CSV file: file:///home/enter1994/notebook/Spark/January%20Flight%20Delay/Jan_2020_ontime.csv
# [Stage 26:>                                                         (0 + 1) / 1]
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+
# |DAY_OF_MONTH|DAY_OF_WEEK|OP_UNIQUE_CARRIER|OP_CARRIER_AIRLINE_ID|OP_CARRIER|TAIL_NUM|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN_AIRPORT_SEQ_ID|ORIGIN|DEST_AIRPORT_ID|DEST_AIRPORT_SEQ_ID|DEST|DEP_TIME|DEP_DEL15|DEP_TIME_BLK|ARR_TIME|ARR_DEL15|CANCELLED|DIVERTED|DISTANCE|  _c21|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+
# |           0|          0|                0|                    0|         0|     698|                0|                0|                    0|     0|              0|                  0|   0|    6664|     6699|           0|    7075|     8078|        0|       0|       0|607346|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+------+

# %%
data2019 = data2019.drop('_c21')
data2020 = data2020.drop('_c21')

# %%
# schema = StructType([
#     StructField('OP_UNIQUE_CARRIER', StringType(), True),
#     StructField('ORIGIN', StringType(), True),
#     StructField('DEST', StringType(), True),
#     StructField('DEP_DEL15', FloatType(), True),
#     StructField('DEP_TIME', FloatType(), True),
# ])

data2019 = data2019.withColumn("DEP_DEL15", data2019["DEP_DEL15"].cast(FloatType()))
data2019 = data2019.withColumn("DEP_TIME", data2019["DEP_TIME"].cast(FloatType()))

data2020 = data2020.withColumn("DEP_DEL15", data2020["DEP_DEL15"].cast(FloatType()))
data2020 = data2020.withColumn("DEP_TIME", data2020["DEP_TIME"].cast(FloatType()))

# %% [markdown]
# (3) 아래 셀에 data2019 의 row 중에서 도착지연이 된 row를 담은 delay2019란 dataframe을 생성하시오. 같은 식으로 data2020 의 row 중에서 도착지연이 된 row를 담은 delay2020란 dataframe을 생성하시오. (5점)

# %%
data2019.show()
# Out:
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |DAY_OF_MONTH|DAY_OF_WEEK|OP_UNIQUE_CARRIER|OP_CARRIER_AIRLINE_ID|OP_CARRIER|TAIL_NUM|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN_AIRPORT_SEQ_ID|ORIGIN|DEST_AIRPORT_ID|DEST_AIRPORT_SEQ_ID|DEST|DEP_TIME|DEP_DEL15|DEP_TIME_BLK|ARR_TIME|ARR_DEL15|CANCELLED|DIVERTED|DISTANCE|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |           1|          2|               9E|                20363|        9E|  N8688C|             3280|            11953|              1195302|   GNV|          10397|            1039707| ATL|   601.0|      0.0|   0600-0659|    0722|     0.00|     0.00|    0.00|  300.00|
# |           1|          2|               9E|                20363|        9E|  N348PQ|             3281|            13487|              1348702|   MSP|          11193|            1119302| CVG|  1359.0|      0.0|   1400-1459|    1633|     0.00|     0.00|    0.00|  596.00|
# |           1|          2|               9E|                20363|        9E|  N8896A|             3282|            11433|              1143302|   DTW|          11193|            1119302| CVG|  1215.0|      0.0|   1200-1259|    1329|     0.00|     0.00|    0.00|  229.00|
# |           1|          2|               9E|                20363|        9E|  N8886A|             3283|            15249|              1524906|   TLH|          10397|            1039707| ATL|  1521.0|      0.0|   1500-1559|    1625|     0.00|     0.00|    0.00|  223.00|
# |           1|          2|               9E|                20363|        9E|  N8974C|             3284|            10397|              1039707|   ATL|          11778|            1177801| FSM|  1847.0|      0.0|   1900-1959|    1940|     0.00|     0.00|    0.00|  579.00|
# |           1|          2|               9E|                20363|        9E|  N927EV|             3285|            11267|              1126702|   DAY|          13487|            1348702| MSP|   853.0|      0.0|   0900-0959|    0953|     0.00|     0.00|    0.00|  574.00|
# |           1|          2|               9E|                20363|        9E|  N915XJ|             3286|            12448|              1244807|   JAN|          10397|            1039707| ATL|  1553.0|      0.0|   1500-1559|    1832|     0.00|     0.00|    0.00|  341.00|
# |           1|          2|               9E|                20363|        9E|  N295PQ|             3287|            12953|              1295304|   LGA|          11193|            1119302| CVG|  1551.0|      0.0|   1500-1559|    1824|     0.00|     0.00|    0.00|  585.00|
# |           1|          2|               9E|                20363|        9E|  N337PQ|             3288|            12451|              1245102|   JAX|          12953|            1295304| LGA|  1037.0|      0.0|   1000-1059|    1239|     0.00|     0.00|    0.00|  833.00|
# |           1|          2|               9E|                20363|        9E|  N311PQ|             3289|            10397|              1039707|   ATL|          10685|            1068502| BMI|  1245.0|      0.0|   1200-1259|    1318|     0.00|     0.00|    0.00|  533.00|
# |           1|          2|               9E|                20363|        9E|  N311PQ|             3289|            10685|              1068502|   BMI|          10397|            1039707| ATL|  1410.0|      0.0|   1400-1459|    1700|     0.00|     0.00|    0.00|  533.00|
# |           1|          2|               9E|                20363|        9E|  N931XJ|             3290|            10874|              1087402|   CAK|          10397|            1039707| ATL|   557.0|      0.0|   0600-0659|    0737|     0.00|     0.00|    0.00|  528.00|
# |           1|          2|               9E|                20363|        9E|  N800AY|             3291|            11433|              1143302|   DTW|          11267|            1126702| DAY|  1552.0|      0.0|   1500-1559|    1738|     1.00|     0.00|    0.00|  166.00|
# |           1|          2|               9E|                20363|        9E|  N927EV|             3292|            13487|              1348702|   MSP|          11267|            1126702| DAY|  2029.0|      0.0|   2000-2059|    2259|     0.00|     0.00|    0.00|  574.00|
# |           1|          2|               9E|                20363|        9E|  N600LR|             3293|            14100|              1410005|   PHL|          11433|            1143302| DTW|  1312.0|      0.0|   1300-1359|    1454|     0.00|     0.00|    0.00|  453.00|
# |           1|          2|               9E|                20363|        9E|  N840AY|             3294|            12478|              1247805|   JFK|          14524|            1452401| RIC|  1450.0|      0.0|   1400-1459|    1637|     0.00|     0.00|    0.00|  288.00|
# |           1|          2|               9E|                20363|        9E|  N232PQ|             3295|            11433|              1143302|   DTW|          11618|            1161802| EWR|  1353.0|      1.0|   1200-1259|    1521|     1.00|     0.00|    0.00|  488.00|
# |           1|          2|               9E|                20363|        9E|  N8970D|             3296|            10208|              1020803|   AGS|          10397|            1039707| ATL|  1148.0|      0.0|   1100-1159|    1236|     0.00|     0.00|    0.00|  143.00|
# |           1|          2|               9E|                20363|        9E|  N8970D|             3296|            10397|              1039707|   ATL|          10208|            1020803| AGS|  1020.0|      0.0|   1000-1059|    1111|     0.00|     0.00|    0.00|  143.00|
# |           1|          2|               9E|                20363|        9E|  N304PQ|             3297|            11433|              1143302|   DTW|          11193|            1119302| CVG|   817.0|      0.0|   0800-0859|    0932|     0.00|     0.00|    0.00|  229.00|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# only showing top 20 rows

# %%
delay2019 = data2019.filter(data2019['DEP_DEL15']==1.0)
delay2020 = data2020.filter(data2020['DEP_DEL15']==1.0)

# %%
delay2019.show()
# Out:
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |DAY_OF_MONTH|DAY_OF_WEEK|OP_UNIQUE_CARRIER|OP_CARRIER_AIRLINE_ID|OP_CARRIER|TAIL_NUM|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN_AIRPORT_SEQ_ID|ORIGIN|DEST_AIRPORT_ID|DEST_AIRPORT_SEQ_ID|DEST|DEP_TIME|DEP_DEL15|DEP_TIME_BLK|ARR_TIME|ARR_DEL15|CANCELLED|DIVERTED|DISTANCE|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |           1|          2|               9E|                20363|        9E|  N232PQ|             3295|            11433|              1143302|   DTW|          11618|            1161802| EWR|  1353.0|      1.0|   1200-1259|    1521|     1.00|     0.00|    0.00|  488.00|
# |           1|          2|               9E|                20363|        9E|  N905XJ|             3328|            11193|              1119302|   CVG|          13487|            1348702| MSP|   817.0|      1.0|   0700-0759|    0900|     1.00|     0.00|    0.00|  596.00|
# |           1|          2|               9E|                20363|        9E|  N833AY|             3338|            13277|              1327702|   MGM|          10397|            1039707| ATL|  1411.0|      1.0|   1100-1159|    1558|     1.00|     0.00|    0.00|  147.00|
# |           1|          2|               9E|                20363|        9E|  N905XJ|             3344|            13487|              1348702|   MSP|          13871|            1387102| OMA|   939.0|      1.0|   0800-0859|    1043|     0.00|     0.00|    0.00|  282.00|
# |           1|          2|               9E|                20363|        9E|  N833AY|             3355|            10397|              1039707|   ATL|          12323|            1232305| ILM|  1701.0|      1.0|   1600-1659|    1814|     0.00|     0.00|    0.00|  377.00|
# |           1|          2|               9E|                20363|        9E|  N301PQ|             3374|            13487|              1348702|   MSP|          11193|            1119302| CVG|  1100.0|      1.0|   1000-1059|    1339|     1.00|     0.00|    0.00|  596.00|
# |           1|          2|               9E|                20363|        9E|  N308PQ|             3394|            14457|              1445702|   RAP|          13487|            1348702| MSP|   957.0|      1.0|   0700-0759|    1228|     1.00|     0.00|    0.00|  489.00|
# |           1|          2|               9E|                20363|        9E|  N8943A|             3399|            11193|              1119302|   CVG|          11433|            1143302| DTW|  1826.0|      1.0|   1800-1859|    1935|     1.00|     0.00|    0.00|  229.00|
# |           1|          2|               9E|                20363|        9E|  N910XJ|             3405|            11423|              1142307|   DSM|          13487|            1348702| MSP|  1336.0|      1.0|   1300-1359|    1430|     0.00|     0.00|    0.00|  232.00|
# |           1|          2|               9E|                20363|        9E|  N308PQ|             3414|            13487|              1348702|   MSP|          12264|            1226402| IAD|  1308.0|      1.0|   1200-1259|    1612|     0.00|     0.00|    0.00|  908.00|
# |           1|          2|               9E|                20363|        9E|  N166PQ|             3425|            12264|              1226402|   IAD|          13487|            1348702| MSP|  1450.0|      1.0|   1400-1459|    1645|     1.00|     0.00|    0.00|  908.00|
# |           1|          2|               9E|                20363|        9E|  N166PQ|             3425|            13487|              1348702|   MSP|          12264|            1226402| IAD|  1058.0|      1.0|   1000-1059|    1412|     1.00|     0.00|    0.00|  908.00|
# |           1|          2|               9E|                20363|        9E|  N903XJ|             3435|            11298|              1129806|   DFW|          13487|            1348702| MSP|  1122.0|      1.0|   1100-1159|    1318|     0.00|     0.00|    0.00|  852.00|
# |           1|          2|               9E|                20363|        9E|  N917XJ|             3438|            12953|              1295304|   LGA|          11193|            1119302| CVG|   958.0|      1.0|   0900-0959|    1210|     0.00|     0.00|    0.00|  585.00|
# |           1|          2|               9E|                20363|        9E|  N298PQ|             5389|            12206|              1220605|   HRL|          13487|            1348702| MSP|  1605.0|      1.0|   1500-1559|    1851|     0.00|     0.00|    0.00| 1310.00|
# |           1|          2|               9E|                20363|        9E|  N607LR|             5434|            10397|              1039707|   ATL|          12217|            1221702| HSV|  1438.0|      1.0|   1400-1459|    1425|     0.00|     0.00|    0.00|  151.00|
# |           1|          2|               9E|                20363|        9E|  N301PQ|             5438|            11193|              1119302|   CVG|          10721|            1072102| BOS|  1414.0|      1.0|   1300-1359|    1558|     0.00|     0.00|    0.00|  752.00|
# |           1|          2|               AA|                19805|        AA|  N838NN|              363|            10693|              1069302|   BNA|          12892|            1289208| LAX|  2014.0|      1.0|   1900-1959|    2251|     1.00|     0.00|    0.00| 1797.00|
# |           1|          2|               AA|                19805|        AA|  N838NN|              363|            12892|              1289208|   LAX|          10693|            1069302| BNA|  1327.0|      1.0|   1200-1259|    1926|     1.00|     0.00|    0.00| 1797.00|
# |           1|          2|               AA|                19805|        AA|  N820AL|              366|            12892|              1289208|   LAX|          11298|            1129806| DFW|  1531.0|      1.0|   1500-1559|    2018|     0.00|     0.00|    0.00| 1235.00|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# (4) 아래 셀에 delay2019 의 row 중에서 도착시간이 정오(1200) 보다 이른 (<) row 를 담은 dataframe인 변수 이름 df1를 생성하시오. 또한 같은 식으로 delay2020 의 row 중에서 도착시간이 정오(1200) 보다 늦은 (>=) row 를 담은 dataframe인 변수 이름 df2를 생성하시오. (5점)

# %%
df1 = delay2019.filter(delay2019['DEP_TIME'] < 1200)
df2 = delay2020.filter(delay2020['DEP_TIME'] >= 1200)

# %%
df1.show()
# Out:
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |DAY_OF_MONTH|DAY_OF_WEEK|OP_UNIQUE_CARRIER|OP_CARRIER_AIRLINE_ID|OP_CARRIER|TAIL_NUM|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|ORIGIN_AIRPORT_SEQ_ID|ORIGIN|DEST_AIRPORT_ID|DEST_AIRPORT_SEQ_ID|DEST|DEP_TIME|DEP_DEL15|DEP_TIME_BLK|ARR_TIME|ARR_DEL15|CANCELLED|DIVERTED|DISTANCE|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# |           1|          2|               9E|                20363|        9E|  N905XJ|             3328|            11193|              1119302|   CVG|          13487|            1348702| MSP|   817.0|      1.0|   0700-0759|    0900|     1.00|     0.00|    0.00|  596.00|
# |           1|          2|               9E|                20363|        9E|  N905XJ|             3344|            13487|              1348702|   MSP|          13871|            1387102| OMA|   939.0|      1.0|   0800-0859|    1043|     0.00|     0.00|    0.00|  282.00|
# |           1|          2|               9E|                20363|        9E|  N301PQ|             3374|            13487|              1348702|   MSP|          11193|            1119302| CVG|  1100.0|      1.0|   1000-1059|    1339|     1.00|     0.00|    0.00|  596.00|
# |           1|          2|               9E|                20363|        9E|  N308PQ|             3394|            14457|              1445702|   RAP|          13487|            1348702| MSP|   957.0|      1.0|   0700-0759|    1228|     1.00|     0.00|    0.00|  489.00|
# |           1|          2|               9E|                20363|        9E|  N166PQ|             3425|            13487|              1348702|   MSP|          12264|            1226402| IAD|  1058.0|      1.0|   1000-1059|    1412|     1.00|     0.00|    0.00|  908.00|
# |           1|          2|               9E|                20363|        9E|  N903XJ|             3435|            11298|              1129806|   DFW|          13487|            1348702| MSP|  1122.0|      1.0|   1100-1159|    1318|     0.00|     0.00|    0.00|  852.00|
# |           1|          2|               9E|                20363|        9E|  N917XJ|             3438|            12953|              1295304|   LGA|          11193|            1119302| CVG|   958.0|      1.0|   0900-0959|    1210|     0.00|     0.00|    0.00|  585.00|
# |           1|          2|               AA|                19805|        AA|  N803NN|              372|            14107|              1410702|   PHX|          13487|            1348702| MSP|  1016.0|      1.0|   0900-0959|    1355|     0.00|     0.00|    0.00| 1276.00|
# |           1|          2|               AA|                19805|        AA|  N543UW|             1872|            13930|              1393007|   ORD|          11057|            1105703| CLT|   914.0|      1.0|   0800-0859|    1215|     1.00|     0.00|    0.00|  599.00|
# |           1|          2|               AA|                19805|        AA|  N358PW|             2834|            11433|              1143302|   DTW|          11298|            1129806| DFW|   743.0|      1.0|   0700-0759|    0948|     1.00|     0.00|    0.00|  986.00|
# |           1|          2|               AA|                19805|        AA|  N110AN|                4|            12892|              1289208|   LAX|          12478|            1247805| JFK|  1120.0|      1.0|   1100-1159|    1908|     0.00|     0.00|    0.00| 2475.00|
# |           1|          2|               AA|                19805|        AA|  N881NN|                9|            13495|              1349505|   MSY|          11298|            1129806| DFW|   905.0|      1.0|   0800-0859|    1041|     1.00|     0.00|    0.00|  447.00|
# |           1|          2|               AA|                19805|        AA|  N381AN|               55|            12889|              1288903|   LAS|          14100|            1410005| PHL|   827.0|      1.0|   0600-0659|    1540|     1.00|     0.00|    0.00| 2176.00|
# |           1|          2|               AA|                19805|        AA|  N901NN|              111|            12339|              1233904|   IND|          11057|            1105703| CLT|   633.0|      1.0|   0600-0659|    0801|     0.00|     0.00|    0.00|  427.00|
# |           1|          2|               AA|                19805|        AA|  N9015D|              165|            11503|              1150305|   EGE|          11298|            1129806| DFW|  1145.0|      1.0|   1000-1059|    1458|     1.00|     0.00|    0.00|  721.00|
# |           1|          2|               AA|                19805|        AA|  N133AN|              167|            12892|              1289208|   LAX|          10721|            1072102| BOS|   836.0|      1.0|   0800-0859|    1638|     0.00|     0.00|    0.00| 2611.00|
# |           1|          2|               AA|                19805|        AA|  N156AN|              185|            12889|              1288903|   LAS|          11298|            1129806| DFW|   306.0|      1.0|   0001-0559|    0736|     0.00|     0.00|    0.00| 1055.00|
# |           1|          2|               AA|                19805|        AA|  N936AN|              200|            13930|              1393007|   ORD|          14492|            1449202| RDU|   847.0|      1.0|   0800-0859|    1122|     0.00|     0.00|    0.00|  646.00|
# |           1|          2|               AA|                19805|        AA|  N982AN|              208|            13204|              1320402|   MCO|          13303|            1330303| MIA|   857.0|      1.0|   0800-0859|    1008|     1.00|     0.00|    0.00|  192.00|
# |           1|          2|               AA|                19805|        AA|  N970UY|             1847|            11298|              1129806|   DFW|          14747|            1474703| SEA|   948.0|      1.0|   0900-0959|    1158|     0.00|     0.00|    0.00| 1660.00|
# +------------+-----------+-----------------+---------------------+----------+--------+-----------------+-----------------+---------------------+------+---------------+-------------------+----+--------+---------+------------+--------+---------+---------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# (5) 아래 셀에 df1과 df2 의 row 중에서 ORIGIN과 DEST가 일치하는 row만 남겨 변수명 result의 dataframe을 생성하시오.  (10점)

# %%
result1.show()
# Out:
# +-------------+
# |withinCountry|
# +-------------+
# |   {CVG, MSP}|
# |   {MSP, OMA}|
# |   {MSP, CVG}|
# |   {RAP, MSP}|
# |   {MSP, IAD}|
# |   {DFW, MSP}|
# |   {LGA, CVG}|
# |   {PHX, MSP}|
# |   {ORD, CLT}|
# |   {DTW, DFW}|
# |   {LAX, JFK}|
# |   {MSY, DFW}|
# |   {LAS, PHL}|
# |   {IND, CLT}|
# |   {EGE, DFW}|
# |   {LAX, BOS}|
# |   {LAS, DFW}|
# |   {ORD, RDU}|
# |   {MCO, MIA}|
# |   {DFW, SEA}|
# +-------------+
# only showing top 20 rows

# %%
result1 = df1.selectExpr('(ORIGIN, DEST) as withinCountry')
result2 = df2.selectExpr('(ORIGIN, DEST) as withinCountry')

joinExpression = result1['withinCountry'] == result2['withinCountry']
joinType = 'inner'

result1.join(result2, result1.withinCountry == result2.withinCountry)
# Out:
# DataFrame[withinCountry: struct<ORIGIN:string,DEST:string>, withinCountry: struct<ORIGIN:string,DEST:string>]

# %% [markdown]
# (6) 아래 셀에 result의 ORIGIN과 DEST의 쌍의 가짓수 (즉, distinct한 쌍의 개수)를 세어 출력하시오. (10점)

# %%
result1.distinct().count()
# Out:
# 3921

# %% [markdown]
# ### Question 2.
# Among all flight data in Jan 2019 and Jan 2020 (I mean union of them), what is is maximum numbers that an airline company committed arrival delays in a single days?
#
# ### 문제 2.
# 2019년1월과 2020년1월 데이터의 ORIGIN과 DEST간 비행 기록 중에서, 하루에 한 항공사가 일으킨 도착지연 횟수중에서 최대치는?

# %% [markdown]
# (7) df1이란 변수명으로 delay2019에 YEAR라는 이름의 column을 추가하고 값을 숫자 2019로 채워 넣은 dataframe 을 생성하시오. 같은 식으로 df2란 변수명에는 delay2020에 YEAR라는 이름의 column을 추가하고 값을 숫자 2020로 채워 넣은 dataframe 을 생성하시오. (10점)

# %%
df1 = delay2019.withColumn('YEAR', lit(2019))
df2 = delay2020.withColumn('YEAR', lit(2020))

# %% [markdown]
# (8) df1과 df2의 RDD를 각각 rdd1과 rdd2란 변수에 대입하시오.(5점)

# %%
df1 = df1.select("DAY_OF_MONTH", "YEAR", "OP_UNIQUE_CARRIER")
df2 = df2.select("DAY_OF_MONTH", "YEAR", "OP_UNIQUE_CARRIER")
df1 = df1.withColumn("DAY_OF_MONTH", df1["DAY_OF_MONTH"].cast(IntegerType()))
df2 = df2.withColumn("DAY_OF_MONTH", df2["DAY_OF_MONTH"].cast(IntegerType()))

rdd1 = df1.rdd
rdd2 = df2.rdd

# %% [markdown]
# (9) rdd1과 rdd2를 합친 RDD rdd3을 생성하시오 (5점)

# %%
rdd3 = rdd1.union(rdd2)

# %% [markdown]
# (10) 이제 문제 2를 풀기 위한 아이디어는 다음과 같다.
#
# 1. "DAY_OF_MONTH", "YEAR", "OP_UNIQUE_CARRIER" 이 세 값에 대해 rdd3에 나타나는 횟수를 센다 (즉, 각 항공사별로 그리고 각 날짜별로 delay를 일으킨 횟수를 센다)
# 2. 여러가지 방법이 있지만 우리는 "DAY_OF_MONTH", "YEAR", "OP_UNIQUE_CARRIER" 세 값으로 이루어진 튜플로 reduceByKey를 이용해 그 출연횟수를 세기로 한다.
# 3. 그러기 위해 우선 rdd3의 row로 부터 키-값의 쌍 형태의 RDD를 적절히 생성한다.
# 4. reduceByKey를 이용해 카운트를 하고 map (transformation)과 max (action)를 이용해 답을 구한다.
#
# 우선, 아래 셀에서 Row로 이루어진 rdd3을 적절히 transformation하여 키-값의 쌍 형식의 RDD rdd4를 만든다. (10점)

# %%
rdd4 = rdd3.mapValues()
# Out:
# [Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='9E'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='AA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='MQ'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='G4'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='B6'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='F9'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='HA'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='EV'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='YX'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OH'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='NK'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  Row(DAY_OF_MONTH=1, YEAR=2019, OP_UNIQUE_CARRIER='OO'),
#  ...]

# %% [markdown]
# (11) "DAY_OF_MONTH", "YEAR", "OP_UNIQUE_CARRIER" 세 값으로 이루어진 튜플의 출연횟수를 reduceByKey를 이용해 count한다. 그 결과는 rdd5에 담는다. (10점)

# %% [markdown]
# (12) 출현 횟수중 최대값을 출력한다 (10점)
