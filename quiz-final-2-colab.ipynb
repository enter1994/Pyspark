# %% [markdown]
# ### Data
#
# Downloaded from: https://www.kaggle.com/zynicide/wine-reviews
#
# ### Question 1.
#
# Summary of data set: A row represents information about a bottle of wine including country where it is produced, description written by a sommelier, score points rated in a wine review site, price of a bottle and etc.
#
# Essential columns:
# * country
# * description
#
# Suppose that we want to discover the unique words used in the description of wines produced in a single country. Since the words used rarely in the descriptions are, however, usually uninformative, we are going to count those frequently occur in wine descriptions of each country.
#
# Our strategy to analyze the wine data set is as follows:
# (1) Count how many times each word appears in the descriptions about the wine bottles produced in each country.
# (2) For each country, calculate the set of top-100 frequent words shown in descriptions.
# (3) Then, find the words that appear in the "top-100 frequent word set" of a single country.
#
# ### 문제 1.
#
# 데이터 셋 요약: 각 행의 데이터는 와인에 대한 정보, 즉, 생산국, 소믈리에가 작성한 설명문, 와인 리뷰 사이트에 따른 평점, 병 당 가격 등의 정보를 담고있다.
#
# 본 문제에 사용되는 핵심 컬럼은 다음과 같다.
# * country
# * decription
#
# 와인 설명 글에 사용되는 단어 중에서 오직 한 나라의 와인들을 설명하기 위해서만 사용되는 독특한 단어를 찾고 싶다고 생각해보자. 그러나 나라별로 흔히 사용되지 않는 단어를 제외하고 여러번 등장하는 단어들 사이에서 그러한 독특한 단어를 찾기위해서 나라별로 빈번히 나타나는 단어들을 뽑아서 그중에 오직 한나라의 와인 설명에만 사용되는 단어를 뽑고자 한다.
#
# 아래 코드에서 데이터를 분석하는 과정은 크게 다음과 같다: (1) 각 나라별로 와인 설명문에 등장하는 각 단어들의 출현 빈도를 센다. (2) 각 나라별로 출현빈도수 에 따라 순위 100개의 단어를 뽑는다. (3) 오직 한 나라의 출현빈도수 100위안에 드는 단어를 뽑는다.

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 39 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 58.4 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845513 sha256=d3283599045b8edece8a39df0613746d61932578a018d47ebf7ae05fc9cefc08
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
# create spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("my app").master("local").getOrCreate()

# get context from the session
sc = spark.sparkContext
# Out:
# 22/11/17 08:18:49 WARN Utils: Your hostname, cherry resolves to a loopback address: 127.0.1.1; using 192.168.0.7 instead (on interface enp6s0)
# 22/11/17 08:18:49 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/11/17 08:18:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/11/17 08:18:51 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# (1) 우선 winemag-data-130k-v2.csv 파일을 읽어 컬럼 "country", "description" 만을 남겨 df란 이름의 데이터프레임에 저장하시오 (5점)

# %%
data = spark.read.format('csv').option("sep", ",").option('header', 'true').load('./Wine_review/winemag-data-130k-v2.csv')
df = data.select('Country', 'description')

# %%
df.show()
# Out:
# +---------+--------------------+
# |  Country|         description|
# +---------+--------------------+
# |    Italy|Aromas include tr...|
# | Portugal|This is ripe and ...|
# |       US|Tart and snappy, ...|
# |       US|Pineapple rind, l...|
# |       US|Much like the reg...|
# |    Spain|Blackberry and ra...|
# |    Italy|Here's a bright, ...|
# |   France|This dry and rest...|
# |  Germany|Savory dried thym...|
# |   France|This has great de...|
# |       US|Soft, supple plum...|
# |   France|This is a dry win...|
# |       US|Slightly reduced,...|
# |    Italy|This is dominated...|
# |       US|Building on 150 y...|
# |  Germany|Zesty orange peel...|
# |Argentina|Baked plum, molas...|
# |Argentina|Raw black-cherry ...|
# |    Spain|Desiccated blackb...|
# |       US|Red fruit aromas ...|
# +---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# (2) df에 ***description이 None이거나 country가 None인*** row가 있는지 확인하고 (즉, 그러한 row의 개수를 세어보고 출력해보고고) 있으면 (즉, 둘중에 하나라도 None인 row가 있다면) filter를 이용해 이를 제거하여 그 결과의 RDD를 rdd1이란 이름의 변수에 저장하시오 (10점)

# %%
df.select([count(when(isnull(c), c)).alias(c) for c in df.columns]).show()
# Out:
# +-------+-----------+
# |Country|description|
# +-------+-----------+
# |     63|          1|
# +-------+-----------+

# %%
rdd1 = df.dropna(subset=["Country"])
rdd1 = rdd1.dropna(subset=["description"])
rdd1.show()
# Out:
# +---------+--------------------+
# |  Country|         description|
# +---------+--------------------+
# |    Italy|Aromas include tr...|
# | Portugal|This is ripe and ...|
# |       US|Tart and snappy, ...|
# |       US|Pineapple rind, l...|
# |       US|Much like the reg...|
# |    Spain|Blackberry and ra...|
# |    Italy|Here's a bright, ...|
# |   France|This dry and rest...|
# |  Germany|Savory dried thym...|
# |   France|This has great de...|
# |       US|Soft, supple plum...|
# |   France|This is a dry win...|
# |       US|Slightly reduced,...|
# |    Italy|This is dominated...|
# |       US|Building on 150 y...|
# |  Germany|Zesty orange peel...|
# |Argentina|Baked plum, molas...|
# |Argentina|Raw black-cherry ...|
# |    Spain|Desiccated blackb...|
# |       US|Red fruit aromas ...|
# +---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# (3) rdd에 있는 각 Row의 description을 처리하여 나라별 단어의 출연횟수를 카운트하기 위해 적절한 flatMap을 이용한 transformation을 수행하시오. 즉, description을 띄어쓰기 (" ") 단위로 잘라서 각 단어마다 country 와 단어의 쌍(tuple)을 키로하고 값을 1로 하는 키-값 쌍을 생성하도록 flatMap을 작성하시오. 더불어, 단어는 대소문자를 구분하지 않기 위해 모두 소문자로 바꾸어 두시오. flatMap 수행 결과 RDD는 rdd2 란 이름의 변수에 저장하시오. (10점)

# %%
dftordd = rdd1.rdd.map(lambda x: [x[0].lower(), x[1].lower().split(' ')])

# %%
rdd2 = []

for word in dftordd.collect():
    for j in range(len(word[1])):
        rdd2.append((word[0], word[1][j]))

rdd2 = sc.parallelize(rdd2)

# %% [markdown]
# (4) rdd2의 키 (즉, country와 단어의 쌍의 tuple)를 카운트하는 transformation을 작성하시오. 그 결과는 rdd3에 저장하시오 (10점)

# %%
rdd3 = rdd2.map(lambda x: (x,1)).reduceByKey(lambda x, y: x+y)

# %%
rdd3.collect()
# Out:
# 22/11/17 08:50:59 WARN TaskSetManager: Stage 55 contains a task of very large size (75002 KiB). The maximum recommended task size is 1000 KiB.
# [(('italy', 'aromas'), 11805),
#  (('italy', 'include'), 279),
#  (('italy', 'tropical'), 316),
#  (('italy', 'fruit,'), 2203),
#  (('italy', 'broom,'), 107),
#  (('italy', 'brimstone'), 41),
#  (('italy', 'and'), 52389),
#  (('italy', 'dried'), 3036),
#  (('italy', 'herb.'), 351),
#  (('italy', 'the'), 32393),
#  (('italy', 'palate'), 9330),
#  (('italy', "isn't"), 121),
#  (('italy', 'overly'), 22),
#  (('italy', 'expressive,'), 71),
#  (('italy', 'offering'), 419),
#  (('italy', 'unripened'), 3),
#  (('italy', 'apple,'), 937),
#  (('italy', 'citrus'), 1449),
#  (('italy', 'sage'), 687),
#  (('italy', 'alongside'), 4494),
#  (('italy', 'brisk'), 281),
#  (('italy', 'acidity.'), 2071),
#  (('portugal', 'this'), 5504),
#  (('portugal', 'is'), 7475),
#  (('portugal', 'ripe'), 1831),
#  (('portugal', 'and'), 11689),
#  (('portugal', 'fruity,'), 307),
#  (('portugal', 'a'), 8897),
#  (('portugal', 'wine'), 5204),
#  (('portugal', 'that'), 2531),
#  (('portugal', 'smooth'), 407),
#  (('portugal', 'while'), 519),
#  (('portugal', 'still'), 650),
#  (('portugal', 'structured.'), 50),
#  (('portugal', 'firm'), 594),
#  (('portugal', 'tannins'), 1512),
#  (('portugal', 'are'), 996),
#  (('portugal', 'filled'), 26),
#  (('portugal', 'out'), 387),
#  (('portugal', 'with'), 4940),
#  (('portugal', 'juicy'), 715),
#  (('portugal', 'red'), 830),
#  (('portugal', 'berry'), 595),
#  (('portugal', 'fruits'), 1264),
#  (('portugal', 'freshened'), 14),
#  (('portugal', 'acidity.'), 1060),
#  (('portugal', "it's"), 799),
#  (('portugal', ''), 22),
#  (('portugal', 'already'), 130),
#  (('portugal', 'drinkable,'), 6),
#  (('portugal', 'although'), 304),
#  (('portugal', 'it'), 4421),
#  (('portugal', 'will'), 670),
#  (('portugal', 'certainly'), 113),
#  (('portugal', 'be'), 615),
#  (('portugal', 'better'), 155),
#  (('portugal', 'from'), 3044),
#  (('portugal', '2016.'), 308),
#  (('us', 'tart'), 3161),
#  (('us', 'and'), 148281),
#  (('us', 'snappy,'), 10),
#  (('us', 'the'), 90944),
#  (('us', 'flavors'), 20148),
#  (('us', 'of'), 73142),
#  (('us', 'lime'), 1801),
#  (('us', 'flesh'), 219),
#  (('us', 'rind'), 313),
#  (('us', 'dominate.'), 35),
#  (('us', 'some'), 3762),
#  (('us', 'green'), 3072),
#  (('us', 'pineapple'), 1180),
#  (('us', 'pokes'), 16),
#  (('us', 'through,'), 121),
#  (('us', 'with'), 48938),
#  (('us', 'crisp'), 3047),
#  (('us', 'acidity'), 6498),
#  (('us', 'underscoring'), 19),
#  (('us', 'flavors.'), 6689),
#  (('us', 'wine'), 20412),
#  (('us', 'was'), 1332),
#  (('us', 'all'), 3312),
#  (('us', 'stainless-steel'), 98),
#  (('us', 'fermented.'), 19),
#  (('us', 'rind,'), 125),
#  (('us', 'lemon'), 2804),
#  (('us', 'pith'), 241),
#  (('us', 'orange'), 2094),
#  (('us', 'blossom'), 424),
#  (('us', 'start'), 256),
#  (('us', 'off'), 1205),
#  (('us', 'aromas.'), 653),
#  (('us', 'palate'), 6438),
#  (('us', 'is'), 32121),
#  (('us', 'a'), 76856),
#  (('us', 'bit'), 3058),
#  (('us', 'more'), 4070),
#  (('us', 'opulent,'), 86),
#  (('us', 'notes'), 5475),
#  (('us', 'honey-drizzled'), 4),
#  (('us', 'guava'), 219),
#  (('us', 'mango'), 342),
#  (('us', 'giving'), 647),
#  (('us', 'way'), 795),
#  (('us', 'to'), 23728),
#  (('us', 'slightly'), 2054),
#  (('us', 'astringent,'), 96),
#  (('us', 'semidry'), 49),
#  (('us', 'finish.'), 7736),
#  (('us', 'much'), 1035),
#  (('us', 'like'), 3669),
#  (('us', 'regular'), 144),
#  (('us', 'bottling'), 2028),
#  (('us', 'from'), 13187),
#  (('us', '2012,'), 39),
#  (('us', 'this'), 47637),
#  (('us', 'comes'), 1161),
#  (('us', 'across'), 527),
#  (('us', 'as'), 6974),
#  (('us', 'rather'), 981),
#  (('us', 'rough'), 223),
#  (('us', 'tannic,'), 851),
#  (('us', 'rustic,'), 187),
#  (('us', 'earthy,'), 520),
#  (('us', 'herbal'), 1132),
#  (('us', 'characteristics.'), 41),
#  (('us', 'nonetheless,'), 40),
#  (('us', 'if'), 1072),
#  (('us', 'you'), 1912),
#  (('us', 'think'), 106),
#  (('us', 'it'), 23261),
#  (('us', 'pleasantly'), 233),
#  (('us', 'unfussy'), 28),
#  (('us', 'country'), 41),
#  (('us', 'wine,'), 4690),
#  (('us', "it's"), 17170),
#  (('us', 'good'), 4070),
#  (('us', 'companion'), 110),
#  (('us', 'hearty'), 345),
#  (('us', 'winter'), 18),
#  (('us', 'stew.'), 34),
#  (('spain', 'blackberry'), 709),
#  (('spain', 'and'), 23710),
#  (('spain', 'raspberry'), 631),
#  (('spain', 'aromas'), 4413),
#  (('spain', 'show'), 123),
#  (('spain', 'a'), 8867),
#  (('spain', 'typical'), 64),
#  (('spain', 'navarran'), 24),
#  (('spain', 'whiff'), 40),
#  (('spain', 'of'), 8691),
#  (('spain', 'green'), 567),
#  (('spain', 'herbs'), 188),
#  (('spain', 'and,'), 6),
#  (('spain', 'in'), 2700),
#  (('spain', 'this'), 6149),
#  (('spain', 'case,'), 3),
#  (('spain', 'horseradish.'), 4),
#  (('spain', 'the'), 9689),
#  (('spain', 'mouth,'), 480),
#  (('spain', 'is'), 5419),
#  (('spain', 'fairly'), 166),
#  (('spain', 'full'), 464),
#  (('spain', 'bodied,'), 19),
#  (('spain', 'with'), 8164),
#  (('spain', 'tomatoey'), 38),
#  (('spain', 'acidity.'), 488),
#  (('spain', 'spicy,'), 126),
#  (('spain', 'herbal'), 667),
#  (('spain', 'flavors'), 4743),
#  (('spain', 'complement'), 7),
#  (('spain', 'dark'), 363),
#  (('spain', 'plum'), 1751),
#  (('spain', 'fruit,'), 197),
#  (('spain', 'while'), 1798),
#  (('spain', 'finish'), 2744),
#  (('spain', 'fresh'), 729),
#  (('spain', 'but'), 2697),
#  (('spain', 'grabby.'), 13),
#  (('italy', "here's"), 890),
#  (('italy', 'a'), 21989),
#  (('italy', 'bright,'), 536),
#  (('italy', 'informal'), 282),
#  (('italy', 'red'), 3407),
#  (('italy', 'that'), 5243),
#  (('italy', 'opens'), 3887),
#  (('italy', 'with'), 15931),
#  (('italy', 'of'), 30660),
#  (('italy', 'candied'), 724),
#  (('italy', 'berry,'), 2113),
#  (('italy', 'white'), 4588),
#  (('italy', 'pepper'), 1845),
#  (('italy', 'savory'), 972),
#  (('italy', 'herb'), 1458),
#  (('italy', 'carry'), 680),
#  (('italy', 'over'), 1107),
#  (('italy', 'to'), 5492),
#  (('italy', 'palate.'), 377),
#  (('italy', "it's"), 2583),
#  (('italy', 'balanced'), 501),
#  (('italy', 'fresh'), 2652),
#  (('italy', 'acidity'), 2640),
#  (('italy', 'soft'), 1029),
#  (('italy', 'tannins.'), 3591),
#  (('france', 'this'), 21331),
#  (('france', 'dry'), 2366),
#  (('france', 'and'), 46098),
#  (('france', 'restrained'), 93),
#  (('france', 'wine'), 17508),
#  (('france', 'offers'), 773),
#  (('france', 'spice'), 1811),
#  (('france', 'in'), 7697),
#  (('france', 'profusion.'), 2),
#  (('france', 'balanced'), 1627),
#  (('france', 'with'), 19912),
#  (('france', 'acidity'), 5691),
#  (('france', 'a'), 32975),
#  (('france', 'firm'), 1935),
#  (('france', 'texture,'), 611),
#  (('france', "it's"), 3484),
#  (('france', 'very'), 2490),
#  (('france', 'much'), 499),
#  (('france', 'for'), 3838),
#  (('france', 'food.'), 177),
#  (('germany', 'savory'), 196),
#  (('germany', 'dried'), 145),
#  (('germany', 'thyme'), 4),
#  (('germany', 'notes'), 625),
#  (('germany', 'accent'), 54),
#  (('germany', 'sunnier'), 2),
#  (('germany', 'flavors'), 839),
#  (('germany', 'of'), 3185),
#  (('germany', 'preserved'), 22),
#  (('germany', 'peach'), 570),
#  (('germany', 'in'), 1292),
#  (('germany', 'this'), 2025),
#  (('germany', 'brisk,'), 74),
#  (('germany', 'off-dry'), 282),
#  (('germany', 'wine.'), 234),
#  (('germany', "it's"), 1290),
#  (('germany', 'fruity'), 205),
#  (('germany', 'and'), 5907),
#  (('germany', 'fresh,'), 112),
#  (('germany', 'with'), 1731),
#  (('germany', 'an'), 332),
#  (('germany', 'elegant,'), 40),
#  (('germany', 'sprightly'), 65),
#  (('germany', 'footprint.'), 1),
#  (('france', 'has'), 8532),
#  (('france', 'great'), 1679),
#  (('france', 'depth'), 303),
#  (('france', 'of'), 23168),
#  (('france', 'flavor'), 591),
#  (('france', 'its'), 5398),
#  (('france', 'fresh'), 2924),
#  (('france', 'apple'), 1906),
#  (('france', 'pear'), 1221),
#  (('france', 'fruits'), 3947),
#  (('france', 'touch'), 1712),
#  (('france', 'spice.'), 399),
#  (('france', 'off'), 288),
#  (('france', 'while'), 2162),
#  (('france', 'crisp'), 3150),
#  (('france', 'texture.'), 1392),
#  (('france', 'drink'), 9096),
#  (('france', 'now.'), 2555),
#  (('us', 'soft,'), 1879),
#  (('us', 'supple'), 655),
#  (('us', 'plum'), 2635),
#  (('us', 'envelopes'), 3),
#  (('us', 'an'), 7705),
#  (('us', 'oaky'), 722),
#  (('us', 'structure'), 1358),
#  (('us', 'in'), 34915),
#  (('us', 'cabernet,'), 569),
#  (('us', 'supported'), 252),
#  (('us', 'by'), 8051),
#  (('us', '15%'), 283),
#  (('us', 'merlot.'), 366),
#  (('us', 'coffee'), 1181),
#  (('us', 'chocolate'), 2471),
#  (('us', 'complete'), 198),
#  (('us', 'picture,'), 18),
#  (('us', 'finishing'), 806),
#  (('us', 'strong'), 1390),
#  (('us', 'at'), 4290),
#  (('us', 'end,'), 38),
#  (('us', 'resulting'), 122),
#  (('us', 'value-priced'), 28),
#  (('us', 'attractive'), 252),
#  (('us', 'flavor'), 1638),
#  (('us', 'immediate'), 162),
#  (('us', 'accessibility.'), 3),
#  (('france', 'is'), 26434),
#  (('france', 'wine,'), 3738),
#  (('france', 'spicy,'), 228),
#  (('france', 'tight,'), 461),
#  (('france', 'taut'), 313),
#  (('france', 'texture'), 2126),
#  (('france', 'strongly'), 317),
#  (('france', 'mineral'), 1360),
#  (('france', 'character'), 1978),
#  (('france', 'layered'), 247),
#  (('france', 'citrus'), 1887),
#  (('france', 'as'), 5212),
#  (('france', 'well'), 2800),
#  (('france', 'pepper.'), 85),
#  (('france', 'food'), 176),
#  (('france', 'almost'), 644),
#  (('france', 'aftertaste.'), 1177),
#  (('us', 'reduced,'), 41),
#  (('us', 'offers'), 3846),
#  (('us', 'chalky,'), 86),
#  (('us', 'tannic'), 2036),
#  (('us', 'backbone'), 234),
#  (('us', 'otherwise'), 271),
#  (('us', 'juicy'), 1948),
#  (('us', 'explosion'), 95),
#  (('us', 'rich'), 5294),
#  (('us', 'black'), 10688),
#  (('us', 'cherry,'), 3257),
#  (('us', 'whole'), 226),
#  (('us', 'accented'), 796),
#  (('us', 'throughout'), 267),
#  (('us', 'firm'), 1922),
#  (('us', 'oak'), 5521),
#  (('us', 'cigar'), 237),
#  (('us', 'box.'), 31),
#  (('italy', 'this'), 14487),
#  (('italy', 'is'), 8602),
#  (('italy', 'dominated'), 59),
#  (('italy', 'by'), 3117),
#  (('italy', 'oak'), 1186),
#  (('italy', 'oak-driven'), 240),
#  (('italy', 'roasted'), 576),
#  (('italy', 'coffee'), 860),
#  (('italy', 'bean,'), 152),
#  (('italy', 'espresso,'), 465),
#  (('italy', 'coconut'), 171),
#  (('italy', 'vanilla'), 1152),
#  (('italy', 'palate,'), 1017),
#  (('italy', 'together'), 636),
#  (('italy', 'plum'), 841),
#  (('italy', 'chocolate.'), 160),
#  (('italy', 'astringent,'), 53),
#  (('italy', 'drying'), 555),
#  (('italy', 'tannins'), 3758),
#  (('italy', 'give'), 832),
#  (('italy', 'it'), 5015),
#  (('italy', 'rather'), 627),
#  (('italy', 'abrupt'), 44),
#  (('italy', 'finish.'), 2947),
#  (('us', 'building'), 38),
#  (('us', 'on'), 19547),
#  (('us', '150'), 9),
#  (('us', 'years'), 1348),
#  (('us', 'six'), 535),
#  (('us', 'generations'), 5),
#  (('us', 'winemaking'), 147),
#  (('us', 'tradition,'), 7),
#  (('us', 'winery'), 613),
#  (('us', 'trends'), 14),
#  (('us', 'toward'), 579),
#  (('us', 'leaner'), 55),
#  (('us', 'style,'), 1078),
#  (('us', 'classic'), 891),
#  (('us', 'california'), 626),
#  (('us', 'buttercream'), 62),
#  (('us', 'aroma'), 690),
#  (('us', 'cut'), 630),
#  (('us', 'apple.'), 189),
#  (('us', 'everyday'), 427),
#  (('us', 'sipping'), 99),
#  (('us', 'that'), 13134),
#  (('us', 'range'), 306),
#  (('us', 'pear'), 2117),
#  (('us', 'barely'), 177),
#  (('us', 'ripe'), 6212),
#  (('us', 'prove'), 67),
#  (('us', 'approachable'), 394),
#  (('us', 'but'), 13012),
#  (('us', 'not'), 3903),
#  (('us', 'distinctive.'), 20),
#  (('germany', 'zesty'), 232),
#  (('germany', 'orange'), 129),
#  (('germany', 'peels'), 9),
#  (('germany', 'apple'), 303),
#  (('germany', 'abound'), 41),
#  (('germany', 'sprightly,'), 10),
#  (('germany', 'mineral-toned'), 3),
#  (('germany', 'riesling.'), 565),
#  (('germany', 'off'), 116),
#  (('germany', 'dry'), 388),
#  (('germany', 'on'), 1460),
#  (('germany', 'the'), 2762),
#  (('germany', 'palate,'), 316),
#  (('germany', 'yet'), 505),
#  (('germany', 'racy'), 59),
#  (('germany', 'lean,'), 29),
#  (('germany', 'a'), 2665),
#  (('germany', 'refreshing,'), 32),
#  (('germany', 'easy'), 54),
#  (('germany', 'quaffer'), 9),
#  (('germany', 'wide'), 13),
#  (('germany', 'appeal.'), 14),
#  (('argentina', 'baked'), 346),
#  (('argentina', 'plum,'), 201),
#  (('argentina', 'molasses,'), 13),
#  (('argentina', 'balsamic'), 39),
#  (('argentina', 'vinegar'), 9),
#  (('argentina', 'and'), 13517),
#  (('argentina', 'cheesy'), 28),
#  (('argentina', 'oak'), 537),
#  (('argentina', 'aromas'), 2492),
#  (('argentina', 'feed'), 32),
#  (('argentina', 'into'), 104),
#  (('argentina', 'a'), 4879),
#  (('argentina', 'palate'), 1471),
#  (('argentina', "that's"), 180),
#  (('argentina', 'braced'), 10),
#  (('argentina', 'by'), 355),
#  (('argentina', 'bolt'), 8),
#  (('argentina', 'of'), 4871),
#  (('argentina', 'acidity.'), 206),
#  (('argentina', 'compact'), 27),
#  (('argentina', 'set'), 144),
#  (('argentina', 'saucy'), 65),
#  (('argentina', 'red-berry'), 67),
#  (('argentina', 'plum'), 954),
#  (('argentina', 'flavors'), 2643),
#  (('argentina', 'features'), 60),
#  (('argentina', 'tobacco'), 68),
#  (('argentina', 'peppery'), 156),
#  (('argentina', 'accents,'), 9),
#  (('argentina', 'while'), 985),
#  (('argentina', 'the'), 5844),
#  (('argentina', 'finish'), 1437),
#  (('argentina', 'is'), 2958),
#  (('argentina', 'mildly'), 112),
#  (('argentina', 'green'), 339),
#  (('argentina', 'in'), 1504),
#  (('argentina', 'flavor,'), 17),
#  (('argentina', 'with'), 4869),
#  (('argentina', 'respectable'), 5),
#  (('argentina', 'weight'), 71),
#  (('argentina', 'balance.'), 53),
#  (('argentina', 'raw'), 131),
#  (('argentina', 'black-cherry'), 7),
#  (('argentina', 'are'), 1529),
#  (('argentina', 'direct'), 12),
#  (('argentina', 'simple'), 73),
#  (('argentina', 'but'), 1586),
#  (('argentina', 'good.'), 35),
#  (('argentina', 'this'), 3069),
#  (('argentina', 'has'), 378),
#  (('argentina', 'juicy'), 145),
#  (('argentina', 'feel'), 175),
#  (('argentina', 'that'), 766),
#  (('argentina', 'thickens'), 2),
#  (('argentina', 'over'), 65),
#  (('argentina', 'time,'), 13),
#  (('argentina', 'character'), 66),
#  (('argentina', 'extract'), 20),
#  (('argentina', 'becoming'), 4),
#  (('argentina', 'more'), 362),
#  (('argentina', 'apparent.'), 2),
#  (('argentina', 'flavor'), 168),
#  (('argentina', 'profile'), 50),
#  (('argentina', 'driven'), 10),
#  (('argentina', 'dark-berry'), 29),
#  (('argentina', 'fruits'), 343),
#  (('argentina', 'smoldering'), 3),
#  (('argentina', 'finishes'), 232),
#  (('argentina', 'meaty'), 84),
#  (('argentina', 'hot.'), 19),
#  (('spain', 'desiccated'), 7),
#  (('spain', 'blackberry,'), 404),
#  (('spain', 'leather,'), 89),
#  (('spain', 'charred'), 126),
#  (('spain', 'wood'), 159),
#  (('spain', 'mint'), 83),
#  (('spain', 'carry'), 96),
#  (('spain', 'nose'), 565),
#  (('spain', 'on'), 4066),
#  (('spain', 'full-bodied,'), 23),
#  (('spain', 'tannic,'), 199),
#  (('spain', 'heavily'), 78),
#  (('spain', 'oaked'), 81),
#  (('spain', 'tinto'), 24),
#  (('spain', 'fino.'), 7),
#  (('spain', 'clove'), 92),
#  (('spain', 'woodspice'), 20),
#  (('spain', 'sit'), 27),
#  (('spain', 'top'), 86),
#  (('spain', 'then'), 197),
#  (('spain', 'hickory'), 54),
#  (('spain', 'other'), 127),
#  (('spain', 'forceful'), 30),
#  (('spain', 'oak-based'), 52),
#  (('spain', 'rise'), 33),
#  (('spain', 'up'), 607),
#  (('spain', 'dominate'), 36),
#  (('spain', 'finish.'), 1409),
#  (('us', 'red'), 6832),
#  (('us', 'fruit'), 12857),
#  (('us', 'aromas'), 9772),
#  (('us', 'pervade'), 17),
#  (('us', 'nose,'), 1113),
#  (('us', 'box'), 112),
#  (('us', 'menthol'), 144),
#  (('us', 'riding'), 54),
#  (('us', 'back.'), 60),
#  (('us', 'restrained'), 432),
#  (('us', 'entry,'), 87),
#  (('us', 'opens'), 793),
#  (('us', 'up'), 2692),
#  (('us', 'riper'), 220),
#  (('us', 'cherry'), 9176),
#  (('us', 'specked'), 4),
#  (('us', 'crushed'), 983),
#  (('us', 'pepper.'), 718),
#  (('us', 'blend'), 4953),
#  (('us', 'merlot,'), 1202),
#  (('us', 'cabernet'), 5981),
#  (('us', 'sauvignon'), 2465),
#  (('us', 'franc'), 1102),
#  (('us', 'now'), 2273),
#  (('us', 'ready'), 657),
#  (('us', 'be'), 2787),
#  (('us', 'enjoyed.'), 7),
#  (('us', 'dark'), 4465),
#  (('us', 'berries'), 475),
#  (('us', 'mingle'), 147),
#  (('us', 'ample'), 375),
#  (('us', 'pepper,'), 1068),
#  (('us', 'toasted'), 861),
#  (('us', 'vanilla'), 3712),
#  (('us', 'dusty'), 840),
#  (('us', 'tobacco.'), 239),
#  (('us', 'oak-driven'), 29),
#  (('us', 'nature,'), 40),
#  (('us', 'currant'), 1669),
#  (('us', 'shine'), 117),
#  (('us', 'offering'), 1285),
#  (('us', 'levity.'), 10),
#  (('us', 'sleek'), 190),
#  (('us', 'mix'), 1627),
#  (('us', 'berry,'), 553),
#  (('us', 'stem'), 153),
#  (('us', 'herb,'), 911),
#  (('us', 'along'), 1920),
#  (('us', 'hint'), 1668),
#  (('us', 'chocolate,'), 1153),
#  (('us', 'fair'), 160),
#  (('us', 'value'), 236),
#  (('us', 'widely'), 165),
#  (('us', 'available,'), 14),
#  (('us', 'drink-now'), 10),
#  (('us', 'oregon'), 310),
#  (('us', 'pinot.'), 138),
#  (('us', 'oak-aged'), 18),
#  (('us', 'for'), 10771),
#  (('us', 'months,'), 54),
#  (('us', 'whether'), 39),
#  (('us', 'neutral'), 435),
#  (('us', 'or'), 2925),
#  (('us', 're-staved'), 1),
#  (('us', 'indicated.'), 2),
#  (('italy', 'delicate'), 821),
#  (('italy', 'recall'), 417),
#  (('italy', 'flower'), 1053),
#  (('italy', 'citrus.'), 224),
#  (('italy', 'offers'), 6229),
#  (('italy', 'passion'), 160),
#  (('italy', 'lime'), 182),
#  (('italy', 'peach'), 1157),
#  (('italy', 'hint'), 2315),
#  (('italy', 'mineral'), 1607),
#  (('italy', 'bright'), 3022),
#  (('us', 'geneseo'), 2),
#  (('us', 'district'), 39),
#  (('us', 'sour'), 980),
#  (('us', 'plums'), 295),
#  (('us', 'just'), 2627),
#  (('us', 'enough'), 1070),
#  (('us', 'tempt'), 6),
#  (('us', 'nose.'), 1517),
#  (('us', 'are'), 10563),
#  (('us', 'flat'), 153),
#  (('us', 'first,'), 329),
#  (('us', 'then'), 827),
#  (('us', 'tension'), 256),
#  (('us', 'cherries'), 1346),
#  (('us', 'emerges'), 49),
#  (('us', 'midpalate,'), 263),
#  (('us', 'bolstered'), 122),
#  (('us', 'licorice.'), 222),
#  (('italy', 'prune,'), 421),
#  (('italy', 'blackcurrant,'), 17),
#  (('italy', 'toast'), 435),
#  (('italy', 'through'), 1543),
#  (('italy', 'extracted'), 145),
#  (('italy', 'along'), 1084),
#  (('italy', 'flavors'), 1700),
#  (('italy', 'black'), 6164),
#  (('italy', 'cherry'), 2926),
#  (('italy', 'beans.'), 10),
#  (('italy', 'firm'), 1631),
#  (('italy', 'but'), 3143),
#  (('italy', 'provide'), 805),
#  (('italy', 'framework.'), 327),
#  (('us', 'earth'), 992),
#  (('us', 'intermingle'), 40),
#  (('us', 'around'), 1117),
#  (('us', 'robust'), 558),
#  (('us', 'wet'), 824),
#  (('us', 'forest'), 551),
#  (('us', 'floor'), 225),
#  (('us', 'vineyard-designated'), 93),
#  (('us', 'pinot'), 4031),
#  (('us', 'hails'), 105),
#  (('us', 'high-elevation'), 48),
#  (('us', 'site.'), 71),
#  (('us', 'small'), 429),
#  (('us', 'production,'), 14),
#  (('us', 'intense,'), 154),
#  (('us', 'full-bodied'), 2223),
#  (('us', 'raspberry'), 3192),
#  (('us', 'blackberry'), 3965),
#  (('us', 'steeped'), 24),
#  (('us', 'smoky'), 2034),
#  (('us', 'spice'), 3682),
#  (('us', 'smooth'), 1811),
#  (('us', 'texture.'), 1109),
#  (('italy', 'pretty'), 709),
#  (('italy', 'yellow'), 1460),
#  (('italy', 'stone'), 1223),
#  (('italy', 'fruit'), 4395),
#  (('italy', 'lead'), 1936),
#  (('italy', 'nose.'), 824),
#  (('italy', 'apricot,'), 391),
#  (('italy', 'notes'), 2390),
#  (('italy', 'lightly'), 152),
#  (('italy', 'toasted'), 1473),
#  (('italy', 'crisp'), 1293),
#  (('italy', 'ripe'), 3550),
#  (('italy', 'dark'), 1939),
#  (('italy', 'whiff'), 1855),
#  (('italy', 'cake'), 398),
#  (('italy', 'spice.'), 1250),
#  (('italy', 'soft,'), 551),
#  (('italy', 'sour'), 622),
#  (('italy', 'cherry,'), 4922),
#  (('italy', 'espresso'), 886),
#  (('italy', 'round'), 600),
#  (('italy', 'drink'), 3377),
#  (('italy', 'soon.'), 678),
#  (('italy', 'suggest'), 171),
#  (('italy', 'mature'), 1717),
#  (('italy', 'scorched'), 378),
#  (('italy', 'earth,'), 505),
#  (('italy', 'animal,'), 6),
#  (('italy', 'anise.'), 85),
#  (('italy', 'oak,'), 777),
#  (('italy', 'cocoa'), 90),
#  (('italy', 'dusty'), 220),
#  (('us', 'clarksburg'), 12),
#  (('us', 'becoming'), 93),
#  (('us', 'haven'), 1),
#  (('us', 'chenin'), 79),
#  (('us', 'blanc'), 741),
#  (('us', 'california.'), 128),
#  (('us', 'bottling,'), 564),
#  (('us', 'using'), 103),
#  (('us', 'sourced'), 771),
#  (('us', 'several'), 283),
#  (('us', 'vineyards'), 512),
#  (('us', 'area,'), 39),
#  (('us', 'balanced'), 2073),
#  (('us', 'trace'), 125),
#  (('us', 'sweetness'), 551),
#  (('us', 'background'), 84),
#  (('us', '(1%'), 1),
#  (('us', 'residual'), 493),
#  (('us', 'sugar).'), 1),
#  (('us', 'crisp,'), 748),
#  (('us', 'straightforward'), 347),
#  (('us', 'blessed'), 12),
#  (('us', 'lime.'), 125),
#  (('us', 'drink'), 5348),
#  (('us', 'cold.'), 52),
#  (('france', 'red'), 3539),
#  (('france', 'cherry'), 1021),
#  (('france', 'fruit'), 5687),
#  (('france', 'comes'), 966),
#  (('france', 'laced'), 215),
#  (('france', 'light'), 2013),
#  (('france', 'tannins,'), 733),
#  (('france', 'giving'), 869),
#  (('france', 'bright'), 1816),
#  (('france', 'an'), 3400),
#  (('france', 'open,'), 121),
#  (('france', 'juicy'), 2119),
#  (('france', 'character.'), 1492),
#  (('italy', 'merlot'), 649),
#  (('italy', 'nero'), 438),
#  (('italy', "d'avola"), 219),
#  (('italy', 'form'), 101),
#  (('italy', 'base'), 66),
#  (('italy', 'for'), 1341),
#  (('italy', 'easy'), 672),
#  (('italy', 'wine'), 6508),
#  (('italy', 'would'), 771),
#  (('italy', 'pair'), 1297),
#  (('italy', 'fettuccine'), 7),
#  (('italy', 'meat'), 418),
#  (('italy', 'sauce'), 57),
#  (('italy', 'or'), 1918),
#  (('italy', 'pork'), 105),
#  (('italy', 'roast.'), 10),
#  (('italy', 'quality'), 468),
#  (('italy', 'clean,'), 261),
#  (('italy', 'sharp.'), 15),
#  (('italy', 'part'), 56),
#  (('italy', 'extended'), 3),
#  (('italy', 'calanìca'), 3),
#  (('italy', 'series,'), 1),
#  (('italy', 'grillo-viognier'), 1),
#  (('italy', 'blend'), 2012),
#  (('italy', 'shows'), 2229),
#  (('italy', 'honeysuckle'), 146),
#  (('italy', 'jasmine,'), 87),
#  (('italy', 'backed'), 668),
#  (('italy', 'touches'), 169),
#  (('italy', 'cut'), 216),
#  (('italy', 'grass'), 94),
#  (('italy', 'wild'), 1898),
#  (('italy', 'sage.'), 140),
#  (('italy', 'in'), 5308),
#  (('italy', 'mouth,'), 264),
#  (('italy', 'yellow-fruit'), 3),
#  (('italy', 'flavors.'), 766),
#  (('us', 'rustic'), 593),
#  (('us', 'dry,'), 2935),
#  (('us', 'has'), 8012),
#  (('us', 'berries,'), 418),
#  (('us', 'currants,'), 913),
#  (('us', 'licorice'), 1241),
#  (('us', 'spices.'), 756),
#  (('us', 'made'), 2785),
#  (('us', 'sauvignon.'), 291),
#  (('us', 'shows'), 5769),
#  (('us', 'tart,'), 840),
#  (('us', 'gooseberry'), 158),
#  (('us', 'similar'), 213),
#  (('us', 'new'), 2777),
#  (('us', 'zealand'), 20),
#  (('us', 'blanc.'), 270),
#  (('us', 'other'), 911),
#  (('us', 'include'), 100),
#  (('us', 'tropical'), 1579),
#  (('us', 'fruit,'), 3212),
#  (('us', 'honey.'), 191),
#  (('us', 'unoaked,'), 33),
#  (('us', 'splash'), 209),
#  (('us', 'muscat,'), 19),
#  (('us', 'commendable'), 6),
#  (('us', 'dryness'), 179),
#  (('us', 'acidity.'), 2722),
#  (('us', 'many'), 687),
#  (('us', 'erath'), 14),
#  (('us', '2010'), 205),
#  (('us', 'vineyard'), 2492),
#  (('us', 'designates,'), 20),
#  (('us', 'strongly'), 188),
#  (('us', 'herbal.'), 32),
#  (('us', 'leaf'), 437),
#  (('us', 'herb'), 1886),
#  (('us', 'create'), 73),
#  (('us', 'somewhat'), 842),
#  (('us', 'unripe'), 121),
#  (('us', 'impressions,'), 5),
#  (('us', 'touch'), 2853),
#  (('us', 'bitterness'), 180),
#  (('us', 'passes'), 4),
#  (('us', 'ripeness'), 514),
#  (('us', 'sweet'), 4750),
#  (('us', 'tomatoes.'), 4),
#  (('chile', 'white'), 157),
#  (('chile', 'flower,'), 2),
#  (('chile', 'lychee'), 23),
#  (('chile', 'and'), 15901),
#  (('chile', 'apple'), 386),
#  (('chile', 'aromas'), 2810),
#  (('chile', 'carry'), 65),
#  (('chile', 'the'), 7358),
#  (('chile', 'mellow'), 38),
#  (('chile', 'bouquet.'), 91),
#  (('chile', 'chunky-feeling'), 1),
#  (('chile', 'palate'), 1723),
#  (('chile', 'bears'), 8),
#  (('chile', 'powdery,'), 6),
#  (('chile', 'sweet'), 284),
#  (('chile', 'flavors'), 3094),
#  (('chile', 'of'), 5954),
#  (('chile', 'peach'), 124),
#  (('chile', 'melon,'), 76),
#  (('chile', 'mixed'), 84),
#  (('chile', 'with'), 5679),
#  (('chile', 'greener'), 5),
#  (('chile', 'notes'), 608),
#  (('chile', 'grass'), 44),
#  (('chile', 'lime.'), 25),
#  (('chile', '80%'), 6),
#  (('chile', 'viognier'), 21),
#  (('chile', 'component'), 3),
#  (('chile', 'is'), 3830),
#  (('chile', 'typical'), 90),
#  (('chile', 'warm'), 65),
#  (('chile', 'climate:'), 1),
#  (('chile', 'plump'), 113),
#  (('chile', 'oily,'), 25),
#  (('chile', 'a'), 5894),
#  (('chile', 'short'), 127),
#  (('chile', 'finish.'), 967),
#  (('chile', 'chardonnay'), 97),
#  (('chile', 'fills'), 1),
#  (('chile', 'out'), 151),
#  (('chile', 'blend.'), 37),
#  (('italy', 'concentrated'), 504),
#  (('italy', 'cabernet'), 1271),
#  (('italy', 'cured'), 355),
#  (('italy', 'meat,'), 149),
#  (('italy', 'rosemary.'), 43),
#  (('italy', 'barbecue'), 113),
#  (('italy', 'spice'), 2925),
#  (('italy', 'teriyaki'), 36),
#  (('italy', 'bold,'), 122),
#  (('italy', 'chewy'), 725),
#  (('italy', 'feel.'), 105),
#  (('italy', 'inky'), 160),
#  (('italy', 'color,'), 98),
#  (('italy', 'has'), 2347),
#  (('italy', 'plump'), 142),
#  (('italy', 'blackberry'), 1027),
#  (('italy', 'jam'), 151),
#  (('italy', 'rum'), 129),
#  (('italy', 'cake.'), 54),
#  (('italy', 'on'), 5209),
#  (('italy', 'smooth.'), 40),
#  (('italy', 'natural'), 365),
#  (('italy', 'movement,'), 8),
#  (('italy', 'made'), 1845),
#  (('italy', 'from'), 2381),
#  (('italy', 'organic'), 85),
#  (('italy', 'grapes,'), 225),
#  (('italy', 'label'), 25),
#  (('italy', 'printed'), 1),
#  (('italy', 'vegetable'), 42),
#  (('italy', 'ink'), 4),
#  (('italy', 'recycled'), 1),
#  (('italy', 'paper.'), 1),
#  (('italy', 'very'), 1026),
#  (('italy', 'nice,'), 13),
#  (('italy', 'juicy'), 1911),
#  (('italy', 'berry'), 2006),
#  (('italy', 'flavor'), 84),
#  (('italy', 'catarratto'), 38),
#  (('italy', 'one'), 458),
#  (('italy', "sicily's"), 29),
#  (('italy', 'most'), 279),
#  (('italy', 'widely'), 12),
#  (('italy', 'farmed'), 132),
#  (('italy', 'grape'), 374),
#  (('italy', 'varieties.'), 17),
#  (('italy', 'expression'), 952),
#  (('italy', 'note,'), 34),
#  (('italy', 'almond'), 1406),
#  (('italy', 'blossom'), 195),
#  (('italy', 'touches.'), 9),
#  (('us', 'stiff,'), 61),
#  (('us', 'slowly'), 176),
#  (('us', 'brings'), 1448),
#  (('us', 'brambly'), 428),
#  (('us', 'berry'), 1776),
#  (('us', 'into'), 3730),
#  (('us', 'play,'), 55),
#  (('us', 'earthy'), 1566),
#  (('us', 'herbs.'), 457),
#  (('us', "there's"), 2804),
#  (('us', 'tannins.'), 2762),
#  (('france', 'festive'), 5),
#  (('france', 'soft,'), 1024),
#  (('france', 'ripe'), 6568),
#  (('france', 'acidity,'), 1160),
#  (('france', 'plus'), 97),
#  (('france', 'berry'), 1451),
#  (('france', 'flavor.'), 324),
#  (('us', 'clean,'), 578),
#  (('us', 'brisk'), 1044),
#  (('us', 'mouthfeel'), 1083),
#  (('us', 'gives'), 820),
#  (('us', 'oaked'), 77),
#  (('us', 'instant'), 19),
#  (('us', 'likeability.'), 7),
#  (('us', 'dry'), 4592),
#  (('us', 'streak'), 746),
#  (('us', 'honey'), 853),
#  (('us', 'sweetens'), 8),
#  (('us', 'citrus,'), 627),
#  (('us', 'pair'), 722),
#  (('us', 'asian'), 602),
#  (('us', 'fare,'), 122),
#  (('us', 'ham'), 44),
#  (('us', 'salad'), 55),
#  (('us', 'grapefruit'), 993),
#  (('us', 'sections.'), 1),
#  (('chile', 'berry'), 1509),
#  (('chile', 'aroma'), 37),
#  (('chile', 'comes'), 101),
#  (('chile', 'cola'), 66),
#  (('chile', 'herb'), 158),
#  (('chile', 'notes.'), 324),
#  (('chile', 'tangy'), 101),
#  (('chile', 'racy,'), 50),
#  (('chile', 'it'), 917),
#  (('chile', 'delivers'), 93),
#  (('chile', 'raspberry'), 346),
#  (('chile', 'plum'), 1092),
#  (('chile', 'flavors,'), 153),
#  (('chile', 'modest'), 118),
#  (('us', 'right'), 921),
#  (('us', 'out'), 2161),
#  (('us', 'starting'), 141),
#  (('us', 'blocks'), 74),
#  (('us', 'dripping'), 26),
#  (('us', 'caramel'), 910),
#  (('us', 'notes.'), 870),
#  (('us', 'texture'), 3037),
#  (('us', 'midpalate'), 399),
#  (('us', 'finessed'), 18),
#  (('us', 'graceful,'), 39),
#  (('us', 'drying'), 159),
#  (('us', 'tannins'), 6637),
#  (('us', 'latch'), 4),
#  (('us', 'onto'), 157),
#  (('us', 'eccentric'), 27),
#  (('us', '50%'), 285),
#  (('us', 'tannat,'), 25),
#  (('us', '35%'), 117),
#  (('us', 'petit'), 1413),
#  (('us', 'verdot'), 634),
#  (('us', 'pinotage.'), 5),
#  (('italy', 'spicy,'), 50),
#  (('italy', 'fried'), 89),
#  (('italy', 'seafood'), 74),
#  (('italy', 'spaghetti'), 24),
#  (('italy', 'con'), 9),
#  (('italy', 'vongole.'), 6),
#  (('italy', 'tones'), 1303),
#  (('italy', 'followed'), 653),
#  (('italy', 'nuance.'), 5),
#  (('us', 'white'), 3306),
#  (('us', 'sugar,'), 287),
#  (('us', 'orange,'), 478),
#  (('us', 'vanilla,'), 1215),
#  (('us', 'brightened'), 374),
#  (('us', 'resembles'), 23),
#  (('us', 'paradigm'), 2),
#  (('us', 'blanc,'), 384),
#  (('us', 'bearing'), 51),
#  (('us', 'grapefruit,'), 282),
#  (('us', 'passion'), 40),
#  (('us', 'kiwi;'), 2),
#  (('us', 'sprinkling'), 52),
#  (('us', 'graham'), 104),
#  (('us', 'cracker'), 129),
#  (('us', 'adds'), 755),
#  (('us', 'interest.'), 154),
#  (('us', 'hits'), 261),
#  (('us', 'fleshy'), 364),
#  (('us', 'fist,'), 3),
#  (('us', 'grassy'), 156),
#  (('us', 'provides'), 586),
#  (('us', 'plenty'), 1669),
#  (('us', 'punch.'), 47),
#  (('us', 'apricot-glazed'), 2),
#  (('us', 'roasted'), 775),
#  (('us', 'chicken.'), 74),
#  (('france', 'soft'), 2193),
#  (('france', 'fruity,'), 1049),
#  (('france', 'generous,'), 189),
#  (('france', "that's"), 521),
#  (('france', 'full'), 3100),
#  (('france', 'red-cherry'), 115),
#  (('france', 'gentle'), 350),
#  (('france', 'tannins.'), 1544),
#  (('france', 'it'), 14804),
#  (('france', 'some'), 2195),
#  (('france', 'richness,'), 234),
#  (('france', 'sweet'), 1009),
#  ...]

# %% [markdown]
# (5) groupByKey를 이용하여 나라별로 나타나는 단어와 그 count 정보를 모으고자 한다. 우선은 rdd3을 transformation하여 country를 key로 하고 단어 및 단어의 count의 튜플을 value로하는 RDD를 생성하여 rdd4에 저장하자 (10점)

# %%
rdd4 = rdd3.map(lambda x:(x[0][0], (x[0][1], x[1])))
rdd4.collect()
# Out:
# [('italy', ('aromas', 11805)),
#  ('italy', ('include', 279)),
#  ('italy', ('tropical', 316)),
#  ('italy', ('fruit,', 2203)),
#  ('italy', ('broom,', 107)),
#  ('italy', ('brimstone', 41)),
#  ('italy', ('and', 52389)),
#  ('italy', ('dried', 3036)),
#  ('italy', ('herb.', 351)),
#  ('italy', ('the', 32393)),
#  ('italy', ('palate', 9330)),
#  ('italy', ("isn't", 121)),
#  ('italy', ('overly', 22)),
#  ('italy', ('expressive,', 71)),
#  ('italy', ('offering', 419)),
#  ('italy', ('unripened', 3)),
#  ('italy', ('apple,', 937)),
#  ('italy', ('citrus', 1449)),
#  ('italy', ('sage', 687)),
#  ('italy', ('alongside', 4494)),
#  ('italy', ('brisk', 281)),
#  ('italy', ('acidity.', 2071)),
#  ('portugal', ('this', 5504)),
#  ('portugal', ('is', 7475)),
#  ('portugal', ('ripe', 1831)),
#  ('portugal', ('and', 11689)),
#  ('portugal', ('fruity,', 307)),
#  ('portugal', ('a', 8897)),
#  ('portugal', ('wine', 5204)),
#  ('portugal', ('that', 2531)),
#  ('portugal', ('smooth', 407)),
#  ('portugal', ('while', 519)),
#  ('portugal', ('still', 650)),
#  ('portugal', ('structured.', 50)),
#  ('portugal', ('firm', 594)),
#  ('portugal', ('tannins', 1512)),
#  ('portugal', ('are', 996)),
#  ('portugal', ('filled', 26)),
#  ('portugal', ('out', 387)),
#  ('portugal', ('with', 4940)),
#  ('portugal', ('juicy', 715)),
#  ('portugal', ('red', 830)),
#  ('portugal', ('berry', 595)),
#  ('portugal', ('fruits', 1264)),
#  ('portugal', ('freshened', 14)),
#  ('portugal', ('acidity.', 1060)),
#  ('portugal', ("it's", 799)),
#  ('portugal', ('', 22)),
#  ('portugal', ('already', 130)),
#  ('portugal', ('drinkable,', 6)),
#  ('portugal', ('although', 304)),
#  ('portugal', ('it', 4421)),
#  ('portugal', ('will', 670)),
#  ('portugal', ('certainly', 113)),
#  ('portugal', ('be', 615)),
#  ('portugal', ('better', 155)),
#  ('portugal', ('from', 3044)),
#  ('portugal', ('2016.', 308)),
#  ('us', ('tart', 3161)),
#  ('us', ('and', 148281)),
#  ('us', ('snappy,', 10)),
#  ('us', ('the', 90944)),
#  ('us', ('flavors', 20148)),
#  ('us', ('of', 73142)),
#  ('us', ('lime', 1801)),
#  ('us', ('flesh', 219)),
#  ('us', ('rind', 313)),
#  ('us', ('dominate.', 35)),
#  ('us', ('some', 3762)),
#  ('us', ('green', 3072)),
#  ('us', ('pineapple', 1180)),
#  ('us', ('pokes', 16)),
#  ('us', ('through,', 121)),
#  ('us', ('with', 48938)),
#  ('us', ('crisp', 3047)),
#  ('us', ('acidity', 6498)),
#  ('us', ('underscoring', 19)),
#  ('us', ('flavors.', 6689)),
#  ('us', ('wine', 20412)),
#  ('us', ('was', 1332)),
#  ('us', ('all', 3312)),
#  ('us', ('stainless-steel', 98)),
#  ('us', ('fermented.', 19)),
#  ('us', ('rind,', 125)),
#  ('us', ('lemon', 2804)),
#  ('us', ('pith', 241)),
#  ('us', ('orange', 2094)),
#  ('us', ('blossom', 424)),
#  ('us', ('start', 256)),
#  ('us', ('off', 1205)),
#  ('us', ('aromas.', 653)),
#  ('us', ('palate', 6438)),
#  ('us', ('is', 32121)),
#  ('us', ('a', 76856)),
#  ('us', ('bit', 3058)),
#  ('us', ('more', 4070)),
#  ('us', ('opulent,', 86)),
#  ('us', ('notes', 5475)),
#  ('us', ('honey-drizzled', 4)),
#  ('us', ('guava', 219)),
#  ('us', ('mango', 342)),
#  ('us', ('giving', 647)),
#  ('us', ('way', 795)),
#  ('us', ('to', 23728)),
#  ('us', ('slightly', 2054)),
#  ('us', ('astringent,', 96)),
#  ('us', ('semidry', 49)),
#  ('us', ('finish.', 7736)),
#  ('us', ('much', 1035)),
#  ('us', ('like', 3669)),
#  ('us', ('regular', 144)),
#  ('us', ('bottling', 2028)),
#  ('us', ('from', 13187)),
#  ('us', ('2012,', 39)),
#  ('us', ('this', 47637)),
#  ('us', ('comes', 1161)),
#  ('us', ('across', 527)),
#  ('us', ('as', 6974)),
#  ('us', ('rather', 981)),
#  ('us', ('rough', 223)),
#  ('us', ('tannic,', 851)),
#  ('us', ('rustic,', 187)),
#  ('us', ('earthy,', 520)),
#  ('us', ('herbal', 1132)),
#  ('us', ('characteristics.', 41)),
#  ('us', ('nonetheless,', 40)),
#  ('us', ('if', 1072)),
#  ('us', ('you', 1912)),
#  ('us', ('think', 106)),
#  ('us', ('it', 23261)),
#  ('us', ('pleasantly', 233)),
#  ('us', ('unfussy', 28)),
#  ('us', ('country', 41)),
#  ('us', ('wine,', 4690)),
#  ('us', ("it's", 17170)),
#  ('us', ('good', 4070)),
#  ('us', ('companion', 110)),
#  ('us', ('hearty', 345)),
#  ('us', ('winter', 18)),
#  ('us', ('stew.', 34)),
#  ('spain', ('blackberry', 709)),
#  ('spain', ('and', 23710)),
#  ('spain', ('raspberry', 631)),
#  ('spain', ('aromas', 4413)),
#  ('spain', ('show', 123)),
#  ('spain', ('a', 8867)),
#  ('spain', ('typical', 64)),
#  ('spain', ('navarran', 24)),
#  ('spain', ('whiff', 40)),
#  ('spain', ('of', 8691)),
#  ('spain', ('green', 567)),
#  ('spain', ('herbs', 188)),
#  ('spain', ('and,', 6)),
#  ('spain', ('in', 2700)),
#  ('spain', ('this', 6149)),
#  ('spain', ('case,', 3)),
#  ('spain', ('horseradish.', 4)),
#  ('spain', ('the', 9689)),
#  ('spain', ('mouth,', 480)),
#  ('spain', ('is', 5419)),
#  ('spain', ('fairly', 166)),
#  ('spain', ('full', 464)),
#  ('spain', ('bodied,', 19)),
#  ('spain', ('with', 8164)),
#  ('spain', ('tomatoey', 38)),
#  ('spain', ('acidity.', 488)),
#  ('spain', ('spicy,', 126)),
#  ('spain', ('herbal', 667)),
#  ('spain', ('flavors', 4743)),
#  ('spain', ('complement', 7)),
#  ('spain', ('dark', 363)),
#  ('spain', ('plum', 1751)),
#  ('spain', ('fruit,', 197)),
#  ('spain', ('while', 1798)),
#  ('spain', ('finish', 2744)),
#  ('spain', ('fresh', 729)),
#  ('spain', ('but', 2697)),
#  ('spain', ('grabby.', 13)),
#  ('italy', ("here's", 890)),
#  ('italy', ('a', 21989)),
#  ('italy', ('bright,', 536)),
#  ('italy', ('informal', 282)),
#  ('italy', ('red', 3407)),
#  ('italy', ('that', 5243)),
#  ('italy', ('opens', 3887)),
#  ('italy', ('with', 15931)),
#  ('italy', ('of', 30660)),
#  ('italy', ('candied', 724)),
#  ('italy', ('berry,', 2113)),
#  ('italy', ('white', 4588)),
#  ('italy', ('pepper', 1845)),
#  ('italy', ('savory', 972)),
#  ('italy', ('herb', 1458)),
#  ('italy', ('carry', 680)),
#  ('italy', ('over', 1107)),
#  ('italy', ('to', 5492)),
#  ('italy', ('palate.', 377)),
#  ('italy', ("it's", 2583)),
#  ('italy', ('balanced', 501)),
#  ('italy', ('fresh', 2652)),
#  ('italy', ('acidity', 2640)),
#  ('italy', ('soft', 1029)),
#  ('italy', ('tannins.', 3591)),
#  ('france', ('this', 21331)),
#  ('france', ('dry', 2366)),
#  ('france', ('and', 46098)),
#  ('france', ('restrained', 93)),
#  ('france', ('wine', 17508)),
#  ('france', ('offers', 773)),
#  ('france', ('spice', 1811)),
#  ('france', ('in', 7697)),
#  ('france', ('profusion.', 2)),
#  ('france', ('balanced', 1627)),
#  ('france', ('with', 19912)),
#  ('france', ('acidity', 5691)),
#  ('france', ('a', 32975)),
#  ('france', ('firm', 1935)),
#  ('france', ('texture,', 611)),
#  ('france', ("it's", 3484)),
#  ('france', ('very', 2490)),
#  ('france', ('much', 499)),
#  ('france', ('for', 3838)),
#  ('france', ('food.', 177)),
#  ('germany', ('savory', 196)),
#  ('germany', ('dried', 145)),
#  ('germany', ('thyme', 4)),
#  ('germany', ('notes', 625)),
#  ('germany', ('accent', 54)),
#  ('germany', ('sunnier', 2)),
#  ('germany', ('flavors', 839)),
#  ('germany', ('of', 3185)),
#  ('germany', ('preserved', 22)),
#  ('germany', ('peach', 570)),
#  ('germany', ('in', 1292)),
#  ('germany', ('this', 2025)),
#  ('germany', ('brisk,', 74)),
#  ('germany', ('off-dry', 282)),
#  ('germany', ('wine.', 234)),
#  ('germany', ("it's", 1290)),
#  ('germany', ('fruity', 205)),
#  ('germany', ('and', 5907)),
#  ('germany', ('fresh,', 112)),
#  ('germany', ('with', 1731)),
#  ('germany', ('an', 332)),
#  ('germany', ('elegant,', 40)),
#  ('germany', ('sprightly', 65)),
#  ('germany', ('footprint.', 1)),
#  ('france', ('has', 8532)),
#  ('france', ('great', 1679)),
#  ('france', ('depth', 303)),
#  ('france', ('of', 23168)),
#  ('france', ('flavor', 591)),
#  ('france', ('its', 5398)),
#  ('france', ('fresh', 2924)),
#  ('france', ('apple', 1906)),
#  ('france', ('pear', 1221)),
#  ('france', ('fruits', 3947)),
#  ('france', ('touch', 1712)),
#  ('france', ('spice.', 399)),
#  ('france', ('off', 288)),
#  ('france', ('while', 2162)),
#  ('france', ('crisp', 3150)),
#  ('france', ('texture.', 1392)),
#  ('france', ('drink', 9096)),
#  ('france', ('now.', 2555)),
#  ('us', ('soft,', 1879)),
#  ('us', ('supple', 655)),
#  ('us', ('plum', 2635)),
#  ('us', ('envelopes', 3)),
#  ('us', ('an', 7705)),
#  ('us', ('oaky', 722)),
#  ('us', ('structure', 1358)),
#  ('us', ('in', 34915)),
#  ('us', ('cabernet,', 569)),
#  ('us', ('supported', 252)),
#  ('us', ('by', 8051)),
#  ('us', ('15%', 283)),
#  ('us', ('merlot.', 366)),
#  ('us', ('coffee', 1181)),
#  ('us', ('chocolate', 2471)),
#  ('us', ('complete', 198)),
#  ('us', ('picture,', 18)),
#  ('us', ('finishing', 806)),
#  ('us', ('strong', 1390)),
#  ('us', ('at', 4290)),
#  ('us', ('end,', 38)),
#  ('us', ('resulting', 122)),
#  ('us', ('value-priced', 28)),
#  ('us', ('attractive', 252)),
#  ('us', ('flavor', 1638)),
#  ('us', ('immediate', 162)),
#  ('us', ('accessibility.', 3)),
#  ('france', ('is', 26434)),
#  ('france', ('wine,', 3738)),
#  ('france', ('spicy,', 228)),
#  ('france', ('tight,', 461)),
#  ('france', ('taut', 313)),
#  ('france', ('texture', 2126)),
#  ('france', ('strongly', 317)),
#  ('france', ('mineral', 1360)),
#  ('france', ('character', 1978)),
#  ('france', ('layered', 247)),
#  ('france', ('citrus', 1887)),
#  ('france', ('as', 5212)),
#  ('france', ('well', 2800)),
#  ('france', ('pepper.', 85)),
#  ('france', ('food', 176)),
#  ('france', ('almost', 644)),
#  ('france', ('aftertaste.', 1177)),
#  ('us', ('reduced,', 41)),
#  ('us', ('offers', 3846)),
#  ('us', ('chalky,', 86)),
#  ('us', ('tannic', 2036)),
#  ('us', ('backbone', 234)),
#  ('us', ('otherwise', 271)),
#  ('us', ('juicy', 1948)),
#  ('us', ('explosion', 95)),
#  ('us', ('rich', 5294)),
#  ('us', ('black', 10688)),
#  ('us', ('cherry,', 3257)),
#  ('us', ('whole', 226)),
#  ('us', ('accented', 796)),
#  ('us', ('throughout', 267)),
#  ('us', ('firm', 1922)),
#  ('us', ('oak', 5521)),
#  ('us', ('cigar', 237)),
#  ('us', ('box.', 31)),
#  ('italy', ('this', 14487)),
#  ('italy', ('is', 8602)),
#  ('italy', ('dominated', 59)),
#  ('italy', ('by', 3117)),
#  ('italy', ('oak', 1186)),
#  ('italy', ('oak-driven', 240)),
#  ('italy', ('roasted', 576)),
#  ('italy', ('coffee', 860)),
#  ('italy', ('bean,', 152)),
#  ('italy', ('espresso,', 465)),
#  ('italy', ('coconut', 171)),
#  ('italy', ('vanilla', 1152)),
#  ('italy', ('palate,', 1017)),
#  ('italy', ('together', 636)),
#  ('italy', ('plum', 841)),
#  ('italy', ('chocolate.', 160)),
#  ('italy', ('astringent,', 53)),
#  ('italy', ('drying', 555)),
#  ('italy', ('tannins', 3758)),
#  ('italy', ('give', 832)),
#  ('italy', ('it', 5015)),
#  ('italy', ('rather', 627)),
#  ('italy', ('abrupt', 44)),
#  ('italy', ('finish.', 2947)),
#  ('us', ('building', 38)),
#  ('us', ('on', 19547)),
#  ('us', ('150', 9)),
#  ('us', ('years', 1348)),
#  ('us', ('six', 535)),
#  ('us', ('generations', 5)),
#  ('us', ('winemaking', 147)),
#  ('us', ('tradition,', 7)),
#  ('us', ('winery', 613)),
#  ('us', ('trends', 14)),
#  ('us', ('toward', 579)),
#  ('us', ('leaner', 55)),
#  ('us', ('style,', 1078)),
#  ('us', ('classic', 891)),
#  ('us', ('california', 626)),
#  ('us', ('buttercream', 62)),
#  ('us', ('aroma', 690)),
#  ('us', ('cut', 630)),
#  ('us', ('apple.', 189)),
#  ('us', ('everyday', 427)),
#  ('us', ('sipping', 99)),
#  ('us', ('that', 13134)),
#  ('us', ('range', 306)),
#  ('us', ('pear', 2117)),
#  ('us', ('barely', 177)),
#  ('us', ('ripe', 6212)),
#  ('us', ('prove', 67)),
#  ('us', ('approachable', 394)),
#  ('us', ('but', 13012)),
#  ('us', ('not', 3903)),
#  ('us', ('distinctive.', 20)),
#  ('germany', ('zesty', 232)),
#  ('germany', ('orange', 129)),
#  ('germany', ('peels', 9)),
#  ('germany', ('apple', 303)),
#  ('germany', ('abound', 41)),
#  ('germany', ('sprightly,', 10)),
#  ('germany', ('mineral-toned', 3)),
#  ('germany', ('riesling.', 565)),
#  ('germany', ('off', 116)),
#  ('germany', ('dry', 388)),
#  ('germany', ('on', 1460)),
#  ('germany', ('the', 2762)),
#  ('germany', ('palate,', 316)),
#  ('germany', ('yet', 505)),
#  ('germany', ('racy', 59)),
#  ('germany', ('lean,', 29)),
#  ('germany', ('a', 2665)),
#  ('germany', ('refreshing,', 32)),
#  ('germany', ('easy', 54)),
#  ('germany', ('quaffer', 9)),
#  ('germany', ('wide', 13)),
#  ('germany', ('appeal.', 14)),
#  ('argentina', ('baked', 346)),
#  ('argentina', ('plum,', 201)),
#  ('argentina', ('molasses,', 13)),
#  ('argentina', ('balsamic', 39)),
#  ('argentina', ('vinegar', 9)),
#  ('argentina', ('and', 13517)),
#  ('argentina', ('cheesy', 28)),
#  ('argentina', ('oak', 537)),
#  ('argentina', ('aromas', 2492)),
#  ('argentina', ('feed', 32)),
#  ('argentina', ('into', 104)),
#  ('argentina', ('a', 4879)),
#  ('argentina', ('palate', 1471)),
#  ('argentina', ("that's", 180)),
#  ('argentina', ('braced', 10)),
#  ('argentina', ('by', 355)),
#  ('argentina', ('bolt', 8)),
#  ('argentina', ('of', 4871)),
#  ('argentina', ('acidity.', 206)),
#  ('argentina', ('compact', 27)),
#  ('argentina', ('set', 144)),
#  ('argentina', ('saucy', 65)),
#  ('argentina', ('red-berry', 67)),
#  ('argentina', ('plum', 954)),
#  ('argentina', ('flavors', 2643)),
#  ('argentina', ('features', 60)),
#  ('argentina', ('tobacco', 68)),
#  ('argentina', ('peppery', 156)),
#  ('argentina', ('accents,', 9)),
#  ('argentina', ('while', 985)),
#  ('argentina', ('the', 5844)),
#  ('argentina', ('finish', 1437)),
#  ('argentina', ('is', 2958)),
#  ('argentina', ('mildly', 112)),
#  ('argentina', ('green', 339)),
#  ('argentina', ('in', 1504)),
#  ('argentina', ('flavor,', 17)),
#  ('argentina', ('with', 4869)),
#  ('argentina', ('respectable', 5)),
#  ('argentina', ('weight', 71)),
#  ('argentina', ('balance.', 53)),
#  ('argentina', ('raw', 131)),
#  ('argentina', ('black-cherry', 7)),
#  ('argentina', ('are', 1529)),
#  ('argentina', ('direct', 12)),
#  ('argentina', ('simple', 73)),
#  ('argentina', ('but', 1586)),
#  ('argentina', ('good.', 35)),
#  ('argentina', ('this', 3069)),
#  ('argentina', ('has', 378)),
#  ('argentina', ('juicy', 145)),
#  ('argentina', ('feel', 175)),
#  ('argentina', ('that', 766)),
#  ('argentina', ('thickens', 2)),
#  ('argentina', ('over', 65)),
#  ('argentina', ('time,', 13)),
#  ('argentina', ('character', 66)),
#  ('argentina', ('extract', 20)),
#  ('argentina', ('becoming', 4)),
#  ('argentina', ('more', 362)),
#  ('argentina', ('apparent.', 2)),
#  ('argentina', ('flavor', 168)),
#  ('argentina', ('profile', 50)),
#  ('argentina', ('driven', 10)),
#  ('argentina', ('dark-berry', 29)),
#  ('argentina', ('fruits', 343)),
#  ('argentina', ('smoldering', 3)),
#  ('argentina', ('finishes', 232)),
#  ('argentina', ('meaty', 84)),
#  ('argentina', ('hot.', 19)),
#  ('spain', ('desiccated', 7)),
#  ('spain', ('blackberry,', 404)),
#  ('spain', ('leather,', 89)),
#  ('spain', ('charred', 126)),
#  ('spain', ('wood', 159)),
#  ('spain', ('mint', 83)),
#  ('spain', ('carry', 96)),
#  ('spain', ('nose', 565)),
#  ('spain', ('on', 4066)),
#  ('spain', ('full-bodied,', 23)),
#  ('spain', ('tannic,', 199)),
#  ('spain', ('heavily', 78)),
#  ('spain', ('oaked', 81)),
#  ('spain', ('tinto', 24)),
#  ('spain', ('fino.', 7)),
#  ('spain', ('clove', 92)),
#  ('spain', ('woodspice', 20)),
#  ('spain', ('sit', 27)),
#  ('spain', ('top', 86)),
#  ('spain', ('then', 197)),
#  ('spain', ('hickory', 54)),
#  ('spain', ('other', 127)),
#  ('spain', ('forceful', 30)),
#  ('spain', ('oak-based', 52)),
#  ('spain', ('rise', 33)),
#  ('spain', ('up', 607)),
#  ('spain', ('dominate', 36)),
#  ('spain', ('finish.', 1409)),
#  ('us', ('red', 6832)),
#  ('us', ('fruit', 12857)),
#  ('us', ('aromas', 9772)),
#  ('us', ('pervade', 17)),
#  ('us', ('nose,', 1113)),
#  ('us', ('box', 112)),
#  ('us', ('menthol', 144)),
#  ('us', ('riding', 54)),
#  ('us', ('back.', 60)),
#  ('us', ('restrained', 432)),
#  ('us', ('entry,', 87)),
#  ('us', ('opens', 793)),
#  ('us', ('up', 2692)),
#  ('us', ('riper', 220)),
#  ('us', ('cherry', 9176)),
#  ('us', ('specked', 4)),
#  ('us', ('crushed', 983)),
#  ('us', ('pepper.', 718)),
#  ('us', ('blend', 4953)),
#  ('us', ('merlot,', 1202)),
#  ('us', ('cabernet', 5981)),
#  ('us', ('sauvignon', 2465)),
#  ('us', ('franc', 1102)),
#  ('us', ('now', 2273)),
#  ('us', ('ready', 657)),
#  ('us', ('be', 2787)),
#  ('us', ('enjoyed.', 7)),
#  ('us', ('dark', 4465)),
#  ('us', ('berries', 475)),
#  ('us', ('mingle', 147)),
#  ('us', ('ample', 375)),
#  ('us', ('pepper,', 1068)),
#  ('us', ('toasted', 861)),
#  ('us', ('vanilla', 3712)),
#  ('us', ('dusty', 840)),
#  ('us', ('tobacco.', 239)),
#  ('us', ('oak-driven', 29)),
#  ('us', ('nature,', 40)),
#  ('us', ('currant', 1669)),
#  ('us', ('shine', 117)),
#  ('us', ('offering', 1285)),
#  ('us', ('levity.', 10)),
#  ('us', ('sleek', 190)),
#  ('us', ('mix', 1627)),
#  ('us', ('berry,', 553)),
#  ('us', ('stem', 153)),
#  ('us', ('herb,', 911)),
#  ('us', ('along', 1920)),
#  ('us', ('hint', 1668)),
#  ('us', ('chocolate,', 1153)),
#  ('us', ('fair', 160)),
#  ('us', ('value', 236)),
#  ('us', ('widely', 165)),
#  ('us', ('available,', 14)),
#  ('us', ('drink-now', 10)),
#  ('us', ('oregon', 310)),
#  ('us', ('pinot.', 138)),
#  ('us', ('oak-aged', 18)),
#  ('us', ('for', 10771)),
#  ('us', ('months,', 54)),
#  ('us', ('whether', 39)),
#  ('us', ('neutral', 435)),
#  ('us', ('or', 2925)),
#  ('us', ('re-staved', 1)),
#  ('us', ('indicated.', 2)),
#  ('italy', ('delicate', 821)),
#  ('italy', ('recall', 417)),
#  ('italy', ('flower', 1053)),
#  ('italy', ('citrus.', 224)),
#  ('italy', ('offers', 6229)),
#  ('italy', ('passion', 160)),
#  ('italy', ('lime', 182)),
#  ('italy', ('peach', 1157)),
#  ('italy', ('hint', 2315)),
#  ('italy', ('mineral', 1607)),
#  ('italy', ('bright', 3022)),
#  ('us', ('geneseo', 2)),
#  ('us', ('district', 39)),
#  ('us', ('sour', 980)),
#  ('us', ('plums', 295)),
#  ('us', ('just', 2627)),
#  ('us', ('enough', 1070)),
#  ('us', ('tempt', 6)),
#  ('us', ('nose.', 1517)),
#  ('us', ('are', 10563)),
#  ('us', ('flat', 153)),
#  ('us', ('first,', 329)),
#  ('us', ('then', 827)),
#  ('us', ('tension', 256)),
#  ('us', ('cherries', 1346)),
#  ('us', ('emerges', 49)),
#  ('us', ('midpalate,', 263)),
#  ('us', ('bolstered', 122)),
#  ('us', ('licorice.', 222)),
#  ('italy', ('prune,', 421)),
#  ('italy', ('blackcurrant,', 17)),
#  ('italy', ('toast', 435)),
#  ('italy', ('through', 1543)),
#  ('italy', ('extracted', 145)),
#  ('italy', ('along', 1084)),
#  ('italy', ('flavors', 1700)),
#  ('italy', ('black', 6164)),
#  ('italy', ('cherry', 2926)),
#  ('italy', ('beans.', 10)),
#  ('italy', ('firm', 1631)),
#  ('italy', ('but', 3143)),
#  ('italy', ('provide', 805)),
#  ('italy', ('framework.', 327)),
#  ('us', ('earth', 992)),
#  ('us', ('intermingle', 40)),
#  ('us', ('around', 1117)),
#  ('us', ('robust', 558)),
#  ('us', ('wet', 824)),
#  ('us', ('forest', 551)),
#  ('us', ('floor', 225)),
#  ('us', ('vineyard-designated', 93)),
#  ('us', ('pinot', 4031)),
#  ('us', ('hails', 105)),
#  ('us', ('high-elevation', 48)),
#  ('us', ('site.', 71)),
#  ('us', ('small', 429)),
#  ('us', ('production,', 14)),
#  ('us', ('intense,', 154)),
#  ('us', ('full-bodied', 2223)),
#  ('us', ('raspberry', 3192)),
#  ('us', ('blackberry', 3965)),
#  ('us', ('steeped', 24)),
#  ('us', ('smoky', 2034)),
#  ('us', ('spice', 3682)),
#  ('us', ('smooth', 1811)),
#  ('us', ('texture.', 1109)),
#  ('italy', ('pretty', 709)),
#  ('italy', ('yellow', 1460)),
#  ('italy', ('stone', 1223)),
#  ('italy', ('fruit', 4395)),
#  ('italy', ('lead', 1936)),
#  ('italy', ('nose.', 824)),
#  ('italy', ('apricot,', 391)),
#  ('italy', ('notes', 2390)),
#  ('italy', ('lightly', 152)),
#  ('italy', ('toasted', 1473)),
#  ('italy', ('crisp', 1293)),
#  ('italy', ('ripe', 3550)),
#  ('italy', ('dark', 1939)),
#  ('italy', ('whiff', 1855)),
#  ('italy', ('cake', 398)),
#  ('italy', ('spice.', 1250)),
#  ('italy', ('soft,', 551)),
#  ('italy', ('sour', 622)),
#  ('italy', ('cherry,', 4922)),
#  ('italy', ('espresso', 886)),
#  ('italy', ('round', 600)),
#  ('italy', ('drink', 3377)),
#  ('italy', ('soon.', 678)),
#  ('italy', ('suggest', 171)),
#  ('italy', ('mature', 1717)),
#  ('italy', ('scorched', 378)),
#  ('italy', ('earth,', 505)),
#  ('italy', ('animal,', 6)),
#  ('italy', ('anise.', 85)),
#  ('italy', ('oak,', 777)),
#  ('italy', ('cocoa', 90)),
#  ('italy', ('dusty', 220)),
#  ('us', ('clarksburg', 12)),
#  ('us', ('becoming', 93)),
#  ('us', ('haven', 1)),
#  ('us', ('chenin', 79)),
#  ('us', ('blanc', 741)),
#  ('us', ('california.', 128)),
#  ('us', ('bottling,', 564)),
#  ('us', ('using', 103)),
#  ('us', ('sourced', 771)),
#  ('us', ('several', 283)),
#  ('us', ('vineyards', 512)),
#  ('us', ('area,', 39)),
#  ('us', ('balanced', 2073)),
#  ('us', ('trace', 125)),
#  ('us', ('sweetness', 551)),
#  ('us', ('background', 84)),
#  ('us', ('(1%', 1)),
#  ('us', ('residual', 493)),
#  ('us', ('sugar).', 1)),
#  ('us', ('crisp,', 748)),
#  ('us', ('straightforward', 347)),
#  ('us', ('blessed', 12)),
#  ('us', ('lime.', 125)),
#  ('us', ('drink', 5348)),
#  ('us', ('cold.', 52)),
#  ('france', ('red', 3539)),
#  ('france', ('cherry', 1021)),
#  ('france', ('fruit', 5687)),
#  ('france', ('comes', 966)),
#  ('france', ('laced', 215)),
#  ('france', ('light', 2013)),
#  ('france', ('tannins,', 733)),
#  ('france', ('giving', 869)),
#  ('france', ('bright', 1816)),
#  ('france', ('an', 3400)),
#  ('france', ('open,', 121)),
#  ('france', ('juicy', 2119)),
#  ('france', ('character.', 1492)),
#  ('italy', ('merlot', 649)),
#  ('italy', ('nero', 438)),
#  ('italy', ("d'avola", 219)),
#  ('italy', ('form', 101)),
#  ('italy', ('base', 66)),
#  ('italy', ('for', 1341)),
#  ('italy', ('easy', 672)),
#  ('italy', ('wine', 6508)),
#  ('italy', ('would', 771)),
#  ('italy', ('pair', 1297)),
#  ('italy', ('fettuccine', 7)),
#  ('italy', ('meat', 418)),
#  ('italy', ('sauce', 57)),
#  ('italy', ('or', 1918)),
#  ('italy', ('pork', 105)),
#  ('italy', ('roast.', 10)),
#  ('italy', ('quality', 468)),
#  ('italy', ('clean,', 261)),
#  ('italy', ('sharp.', 15)),
#  ('italy', ('part', 56)),
#  ('italy', ('extended', 3)),
#  ('italy', ('calanìca', 3)),
#  ('italy', ('series,', 1)),
#  ('italy', ('grillo-viognier', 1)),
#  ('italy', ('blend', 2012)),
#  ('italy', ('shows', 2229)),
#  ('italy', ('honeysuckle', 146)),
#  ('italy', ('jasmine,', 87)),
#  ('italy', ('backed', 668)),
#  ('italy', ('touches', 169)),
#  ('italy', ('cut', 216)),
#  ('italy', ('grass', 94)),
#  ('italy', ('wild', 1898)),
#  ('italy', ('sage.', 140)),
#  ('italy', ('in', 5308)),
#  ('italy', ('mouth,', 264)),
#  ('italy', ('yellow-fruit', 3)),
#  ('italy', ('flavors.', 766)),
#  ('us', ('rustic', 593)),
#  ('us', ('dry,', 2935)),
#  ('us', ('has', 8012)),
#  ('us', ('berries,', 418)),
#  ('us', ('currants,', 913)),
#  ('us', ('licorice', 1241)),
#  ('us', ('spices.', 756)),
#  ('us', ('made', 2785)),
#  ('us', ('sauvignon.', 291)),
#  ('us', ('shows', 5769)),
#  ('us', ('tart,', 840)),
#  ('us', ('gooseberry', 158)),
#  ('us', ('similar', 213)),
#  ('us', ('new', 2777)),
#  ('us', ('zealand', 20)),
#  ('us', ('blanc.', 270)),
#  ('us', ('other', 911)),
#  ('us', ('include', 100)),
#  ('us', ('tropical', 1579)),
#  ('us', ('fruit,', 3212)),
#  ('us', ('honey.', 191)),
#  ('us', ('unoaked,', 33)),
#  ('us', ('splash', 209)),
#  ('us', ('muscat,', 19)),
#  ('us', ('commendable', 6)),
#  ('us', ('dryness', 179)),
#  ('us', ('acidity.', 2722)),
#  ('us', ('many', 687)),
#  ('us', ('erath', 14)),
#  ('us', ('2010', 205)),
#  ('us', ('vineyard', 2492)),
#  ('us', ('designates,', 20)),
#  ('us', ('strongly', 188)),
#  ('us', ('herbal.', 32)),
#  ('us', ('leaf', 437)),
#  ('us', ('herb', 1886)),
#  ('us', ('create', 73)),
#  ('us', ('somewhat', 842)),
#  ('us', ('unripe', 121)),
#  ('us', ('impressions,', 5)),
#  ('us', ('touch', 2853)),
#  ('us', ('bitterness', 180)),
#  ('us', ('passes', 4)),
#  ('us', ('ripeness', 514)),
#  ('us', ('sweet', 4750)),
#  ('us', ('tomatoes.', 4)),
#  ('chile', ('white', 157)),
#  ('chile', ('flower,', 2)),
#  ('chile', ('lychee', 23)),
#  ('chile', ('and', 15901)),
#  ('chile', ('apple', 386)),
#  ('chile', ('aromas', 2810)),
#  ('chile', ('carry', 65)),
#  ('chile', ('the', 7358)),
#  ('chile', ('mellow', 38)),
#  ('chile', ('bouquet.', 91)),
#  ('chile', ('chunky-feeling', 1)),
#  ('chile', ('palate', 1723)),
#  ('chile', ('bears', 8)),
#  ('chile', ('powdery,', 6)),
#  ('chile', ('sweet', 284)),
#  ('chile', ('flavors', 3094)),
#  ('chile', ('of', 5954)),
#  ('chile', ('peach', 124)),
#  ('chile', ('melon,', 76)),
#  ('chile', ('mixed', 84)),
#  ('chile', ('with', 5679)),
#  ('chile', ('greener', 5)),
#  ('chile', ('notes', 608)),
#  ('chile', ('grass', 44)),
#  ('chile', ('lime.', 25)),
#  ('chile', ('80%', 6)),
#  ('chile', ('viognier', 21)),
#  ('chile', ('component', 3)),
#  ('chile', ('is', 3830)),
#  ('chile', ('typical', 90)),
#  ('chile', ('warm', 65)),
#  ('chile', ('climate:', 1)),
#  ('chile', ('plump', 113)),
#  ('chile', ('oily,', 25)),
#  ('chile', ('a', 5894)),
#  ('chile', ('short', 127)),
#  ('chile', ('finish.', 967)),
#  ('chile', ('chardonnay', 97)),
#  ('chile', ('fills', 1)),
#  ('chile', ('out', 151)),
#  ('chile', ('blend.', 37)),
#  ('italy', ('concentrated', 504)),
#  ('italy', ('cabernet', 1271)),
#  ('italy', ('cured', 355)),
#  ('italy', ('meat,', 149)),
#  ('italy', ('rosemary.', 43)),
#  ('italy', ('barbecue', 113)),
#  ('italy', ('spice', 2925)),
#  ('italy', ('teriyaki', 36)),
#  ('italy', ('bold,', 122)),
#  ('italy', ('chewy', 725)),
#  ('italy', ('feel.', 105)),
#  ('italy', ('inky', 160)),
#  ('italy', ('color,', 98)),
#  ('italy', ('has', 2347)),
#  ('italy', ('plump', 142)),
#  ('italy', ('blackberry', 1027)),
#  ('italy', ('jam', 151)),
#  ('italy', ('rum', 129)),
#  ('italy', ('cake.', 54)),
#  ('italy', ('on', 5209)),
#  ('italy', ('smooth.', 40)),
#  ('italy', ('natural', 365)),
#  ('italy', ('movement,', 8)),
#  ('italy', ('made', 1845)),
#  ('italy', ('from', 2381)),
#  ('italy', ('organic', 85)),
#  ('italy', ('grapes,', 225)),
#  ('italy', ('label', 25)),
#  ('italy', ('printed', 1)),
#  ('italy', ('vegetable', 42)),
#  ('italy', ('ink', 4)),
#  ('italy', ('recycled', 1)),
#  ('italy', ('paper.', 1)),
#  ('italy', ('very', 1026)),
#  ('italy', ('nice,', 13)),
#  ('italy', ('juicy', 1911)),
#  ('italy', ('berry', 2006)),
#  ('italy', ('flavor', 84)),
#  ('italy', ('catarratto', 38)),
#  ('italy', ('one', 458)),
#  ('italy', ("sicily's", 29)),
#  ('italy', ('most', 279)),
#  ('italy', ('widely', 12)),
#  ('italy', ('farmed', 132)),
#  ('italy', ('grape', 374)),
#  ('italy', ('varieties.', 17)),
#  ('italy', ('expression', 952)),
#  ('italy', ('note,', 34)),
#  ('italy', ('almond', 1406)),
#  ('italy', ('blossom', 195)),
#  ('italy', ('touches.', 9)),
#  ('us', ('stiff,', 61)),
#  ('us', ('slowly', 176)),
#  ('us', ('brings', 1448)),
#  ('us', ('brambly', 428)),
#  ('us', ('berry', 1776)),
#  ('us', ('into', 3730)),
#  ('us', ('play,', 55)),
#  ('us', ('earthy', 1566)),
#  ('us', ('herbs.', 457)),
#  ('us', ("there's", 2804)),
#  ('us', ('tannins.', 2762)),
#  ('france', ('festive', 5)),
#  ('france', ('soft,', 1024)),
#  ('france', ('ripe', 6568)),
#  ('france', ('acidity,', 1160)),
#  ('france', ('plus', 97)),
#  ('france', ('berry', 1451)),
#  ('france', ('flavor.', 324)),
#  ('us', ('clean,', 578)),
#  ('us', ('brisk', 1044)),
#  ('us', ('mouthfeel', 1083)),
#  ('us', ('gives', 820)),
#  ('us', ('oaked', 77)),
#  ('us', ('instant', 19)),
#  ('us', ('likeability.', 7)),
#  ('us', ('dry', 4592)),
#  ('us', ('streak', 746)),
#  ('us', ('honey', 853)),
#  ('us', ('sweetens', 8)),
#  ('us', ('citrus,', 627)),
#  ('us', ('pair', 722)),
#  ('us', ('asian', 602)),
#  ('us', ('fare,', 122)),
#  ('us', ('ham', 44)),
#  ('us', ('salad', 55)),
#  ('us', ('grapefruit', 993)),
#  ('us', ('sections.', 1)),
#  ('chile', ('berry', 1509)),
#  ('chile', ('aroma', 37)),
#  ('chile', ('comes', 101)),
#  ('chile', ('cola', 66)),
#  ('chile', ('herb', 158)),
#  ('chile', ('notes.', 324)),
#  ('chile', ('tangy', 101)),
#  ('chile', ('racy,', 50)),
#  ('chile', ('it', 917)),
#  ('chile', ('delivers', 93)),
#  ('chile', ('raspberry', 346)),
#  ('chile', ('plum', 1092)),
#  ('chile', ('flavors,', 153)),
#  ('chile', ('modest', 118)),
#  ('us', ('right', 921)),
#  ('us', ('out', 2161)),
#  ('us', ('starting', 141)),
#  ('us', ('blocks', 74)),
#  ('us', ('dripping', 26)),
#  ('us', ('caramel', 910)),
#  ('us', ('notes.', 870)),
#  ('us', ('texture', 3037)),
#  ('us', ('midpalate', 399)),
#  ('us', ('finessed', 18)),
#  ('us', ('graceful,', 39)),
#  ('us', ('drying', 159)),
#  ('us', ('tannins', 6637)),
#  ('us', ('latch', 4)),
#  ('us', ('onto', 157)),
#  ('us', ('eccentric', 27)),
#  ('us', ('50%', 285)),
#  ('us', ('tannat,', 25)),
#  ('us', ('35%', 117)),
#  ('us', ('petit', 1413)),
#  ('us', ('verdot', 634)),
#  ('us', ('pinotage.', 5)),
#  ('italy', ('spicy,', 50)),
#  ('italy', ('fried', 89)),
#  ('italy', ('seafood', 74)),
#  ('italy', ('spaghetti', 24)),
#  ('italy', ('con', 9)),
#  ('italy', ('vongole.', 6)),
#  ('italy', ('tones', 1303)),
#  ('italy', ('followed', 653)),
#  ('italy', ('nuance.', 5)),
#  ('us', ('white', 3306)),
#  ('us', ('sugar,', 287)),
#  ('us', ('orange,', 478)),
#  ('us', ('vanilla,', 1215)),
#  ('us', ('brightened', 374)),
#  ('us', ('resembles', 23)),
#  ('us', ('paradigm', 2)),
#  ('us', ('blanc,', 384)),
#  ('us', ('bearing', 51)),
#  ('us', ('grapefruit,', 282)),
#  ('us', ('passion', 40)),
#  ('us', ('kiwi;', 2)),
#  ('us', ('sprinkling', 52)),
#  ('us', ('graham', 104)),
#  ('us', ('cracker', 129)),
#  ('us', ('adds', 755)),
#  ('us', ('interest.', 154)),
#  ('us', ('hits', 261)),
#  ('us', ('fleshy', 364)),
#  ('us', ('fist,', 3)),
#  ('us', ('grassy', 156)),
#  ('us', ('provides', 586)),
#  ('us', ('plenty', 1669)),
#  ('us', ('punch.', 47)),
#  ('us', ('apricot-glazed', 2)),
#  ('us', ('roasted', 775)),
#  ('us', ('chicken.', 74)),
#  ('france', ('soft', 2193)),
#  ('france', ('fruity,', 1049)),
#  ('france', ('generous,', 189)),
#  ('france', ("that's", 521)),
#  ('france', ('full', 3100)),
#  ('france', ('red-cherry', 115)),
#  ('france', ('gentle', 350)),
#  ('france', ('tannins.', 1544)),
#  ('france', ('it', 14804)),
#  ('france', ('some', 2195)),
#  ('france', ('richness,', 234)),
#  ('france', ('sweet', 1009)),
#  ...]

# %% [markdown]
# (6) rdd4 에 groupByKey를 적용하여 나라별로 (word, count) 튜플을 모은다. 모든 튜플의 리스트는 count의 내림차순으로 정렬하여 그 결과 RDD를 rdd5에 저장한다 (즉, rdd5는 키가 <U>country</U>, 값은 <U>count 내림차순으로 정렬된 (word, count) 튜플의 리스트</U>가 된다) (15점)
#
# 힌트: 튜플의 리스트를 second element순으로 정렬하는 방법은 아래 예제코드를 참고하면된다.
#
# ````python
# sorted([('abc', 121),('abc', 231),('abc', 148), ('abc',221)], key=lambda x: x[1], reverse=True)
# ````

# %%
rdd5 = rdd4.groupByKey().collect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/enter1994/notebook/Spark/quiz-final-2-colab.ipynb 셀 21 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcherry/home/enter1994/notebook/Spark/quiz-final-2-colab.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> rdd5 = rdd4.groupByKey()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcherry/home/enter1994/notebook/Spark/quiz-final-2-colab.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> rdd5 = sorted(rdd5.collect(), key=lambda x: x[1], reverse=True)
#
# TypeError: '<' not supported between instances of 'ResultIterable' and 'ResultIterable'

# %%
rdd5
# Out:
# [('italy', <pyspark.resultiterable.ResultIterable at 0x7f276ebeb820>),
#  ('portugal', <pyspark.resultiterable.ResultIterable at 0x7f276269cd90>),
#  ('us', <pyspark.resultiterable.ResultIterable at 0x7f276ec1a5b0>),
#  ('spain', <pyspark.resultiterable.ResultIterable at 0x7f276ec1a6d0>),
#  ('france', <pyspark.resultiterable.ResultIterable at 0x7f276ec1afa0>),
#  ('germany', <pyspark.resultiterable.ResultIterable at 0x7f276ec05070>),
#  ('argentina', <pyspark.resultiterable.ResultIterable at 0x7f276ec05fa0>),
#  ('chile', <pyspark.resultiterable.ResultIterable at 0x7f276ec051c0>),
#  ('australia', <pyspark.resultiterable.ResultIterable at 0x7f276ec05520>),
#  ('austria', <pyspark.resultiterable.ResultIterable at 0x7f276ec050d0>),
#  ('south africa', <pyspark.resultiterable.ResultIterable at 0x7f276ebeba90>),
#  ('new zealand', <pyspark.resultiterable.ResultIterable at 0x7f276ebebe20>),
#  ('israel', <pyspark.resultiterable.ResultIterable at 0x7f276ebeb730>),
#  ('hungary', <pyspark.resultiterable.ResultIterable at 0x7f27b2984940>),
#  ('greece', <pyspark.resultiterable.ResultIterable at 0x7f276ebf0970>),
#  ('romania', <pyspark.resultiterable.ResultIterable at 0x7f27625a1b50>),
#  ('mexico', <pyspark.resultiterable.ResultIterable at 0x7f27625a1610>),
#  ('canada', <pyspark.resultiterable.ResultIterable at 0x7f27625a1910>),
#  ('turkey', <pyspark.resultiterable.ResultIterable at 0x7f27625a17c0>),
#  ('czech republic', <pyspark.resultiterable.ResultIterable at 0x7f27625a1100>),
#  ('slovenia', <pyspark.resultiterable.ResultIterable at 0x7f27625a1820>),
#  ('luxembourg', <pyspark.resultiterable.ResultIterable at 0x7f27625a1850>),
#  ('croatia', <pyspark.resultiterable.ResultIterable at 0x7f27625a1c40>),
#  ('georgia', <pyspark.resultiterable.ResultIterable at 0x7f27625a19d0>),
#  ('uruguay', <pyspark.resultiterable.ResultIterable at 0x7f27625a1670>),
#  ('england', <pyspark.resultiterable.ResultIterable at 0x7f27625a1ac0>),
#  ('lebanon', <pyspark.resultiterable.ResultIterable at 0x7f27625a1f70>),
#  ('serbia', <pyspark.resultiterable.ResultIterable at 0x7f27625a1ee0>),
#  ('brazil', <pyspark.resultiterable.ResultIterable at 0x7f27625a1b20>),
#  ('moldova', <pyspark.resultiterable.ResultIterable at 0x7f27625a1af0>),
#  ('morocco', <pyspark.resultiterable.ResultIterable at 0x7f27625a1280>),
#  ('peru', <pyspark.resultiterable.ResultIterable at 0x7f27625a1580>),
#  ('india', <pyspark.resultiterable.ResultIterable at 0x7f2764afc520>),
#  ('bulgaria', <pyspark.resultiterable.ResultIterable at 0x7f2764afc070>),
#  ('cyprus', <pyspark.resultiterable.ResultIterable at 0x7f2764afc730>),
#  ('armenia', <pyspark.resultiterable.ResultIterable at 0x7f2764afcd90>),
#  ('switzerland', <pyspark.resultiterable.ResultIterable at 0x7f2764afc0a0>),
#  ('bosnia and herzegovina',
#   <pyspark.resultiterable.ResultIterable at 0x7f2764afc8b0>),
#  ('90', <pyspark.resultiterable.ResultIterable at 0x7f2764afc2e0>),
#  ('bordeaux-style red blend',
#   <pyspark.resultiterable.ResultIterable at 0x7f2764afc9d0>),
#  ('ukraine', <pyspark.resultiterable.ResultIterable at 0x7f2764afcfd0>),
#  (' fine and extremely polished; hold for 10 years."',
#   <pyspark.resultiterable.ResultIterable at 0x7f2764afcac0>),
#  ('slovakia', <pyspark.resultiterable.ResultIterable at 0x7f2764afc310>),
#  ('macedonia', <pyspark.resultiterable.ResultIterable at 0x7f2761d3b550>),
#  ('china', <pyspark.resultiterable.ResultIterable at 0x7f2761d3b1f0>),
#  ('egypt', <pyspark.resultiterable.ResultIterable at 0x7f2761d3b3a0>)]

# %% [markdown]
# (7) 이제 나라별로 출현빈도가 top-100에 드는 단어들만 남겨서 rdd6에 저장하도록 하자. rdd6의 키는 country가 되고 값은 단어들의 리스트가 되도록 하자. rdd5에 갖고 있던 단어의 출현빈도는 이제 필요없다. (10점)

# %% [markdown]
# (8) 이제 오직 한 나라의 와인 설명에서만 등장하는 단어를 찾기 위해 나라마다의 출현빈도 top-100 단어에 등장하는 단어들이 몇 개 나라의 출현빈도 top-100에 속하는지를 세어보려고 한다. 이를 위해 우선 rdd6에 있는 각 나라별 단어리스트를 flatMap을 이용해 (word, country)의 쌍의 RDD로 변환시킨다. 그 결과는 rdd7이라 이름짓는다. (10점)

# %% [markdown]
# (9) rdd7의 각 단어별로 groupByKey한다. 즉, 단어가 key가 되고 단어가 나오는 나라이름의 리스트가 value가 되는 RDD를 생성하여 rdd8이라 명명하시오. (10점)

# %% [markdown]
# (10) 마지막으로 오직 하나의 나라에서만 사용되는 단어의 수를 count하여 출력한다. (10점)
